# %%
import __future__, sys

import os
import random
from multiprocessing import Process
file=r'C:\Users\Fatima\Desktop\UNcertainity-arabic\bioArabic.xml'
import xml.etree.cElementTree as ET
tree = ET.parse(file)
root = tree.getroot()
for elem in root.getiterator():
    print (elem.tag, elem.attrib)
n=0
for group in root.iter('sentence'):
          print(group.text)
          n+=1

c=0
for neighbor in root.iter('cue'):
    print(neighbor.text)
    c+=1

xx=0
for neighbor in root.iter('cue'):
    if neighbor.text != None:
        print(neighbor.text)
        xx+=1
        
x=0
for neighbor in root.iter('xcope'):
    if neighbor.text != None:
        print(neighbor.text)
        x+=1
# Out:
# Annotation {'created': '18/2/2015', 'creator': 'XMLconverter'}
# DocumentSet {}
# DocumentsA {'type': 'biomedical articles'}
# DocID {'type': 'BMC_ID'}
# DocumentPart {'type': 'Title'}
# sentence {'id': 'S1.1'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S1.2'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S1.3'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S1.4'}
# xcope {'id': 'X1.4.1'}
# cue {'type': 'speculation', 'ref': 'X1.4.1'}
# sentence {'id': 'S1.5'}
# xcope {'id': 'X1.5.1'}
# cue {'type': 'speculation', 'ref': 'X1.5.1'}
# sentence {'id': 'S1.6'}
# sentence {'id': 'S1.7'}
# sentence {'id': 'S1.8'}
# xcope {'id': 'X1.8.1'}
# cue {'type': 'negation', 'ref': 'X1.8.1'}
# DocumentPart {'type': 'SubSectionTitle'}
# sentence {'id': 'S1.9'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S1.10'}
# xcope {'id': 'X1.10.1'}
# cue {'type': 'speculation', 'ref': 'X1.10.1'}
# sentence {'id': 'S1.11'}
# sentence {'id': 'S1.12'}
# sentence {'id': 'S1.13'}
# DocumentPart {'type': ''}
# sentence {'id': 'S1.14'}
# xcope {'id': 'X1.14.3'}
# cue {'type': 'negation', 'ref': 'X1.14.3'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S1.15'}
# sentence {'id': 'S1.16'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S1.17'}
# xcope {'id': 'X1.17.1'}
# cue {'type': 'negation', 'ref': 'X1.17.1'}
# DocumentPart {'type': 'subsectionTitle'}
# sentence {'id': 'S1.18'}
# xcope {'id': 'X1.18.1'}
# cue {'type': 'speculation', 'ref': 'X1.19.1'}
# sentence {'id': 'S1.19'}
# sentence {'id': 'S1.20'}
# sentence {'id': 'S1.21'}
# sentence {'id': 'S1.22'}
# sentence {'id': 'S1.23'}
# sentence {'id': 'S1.24'}
# sentence {'id': 'S1.25'}
# sentence {'id': 'S1.26'}
# sentence {'id': 'S1.27'}
# sentence {'id': 'S1.28'}
# xcope {'id': 'X1.28.1'}
# cue {'type': 'negation', 'ref': 'X1.28.1'}
# xcope {'id': 'X1.28.2'}
# cue {'type': 'negation', 'ref': 'X1.28.2'}
# DocumentsB {'type': 'biomedical articles'}
# DocID {'type': 'BMC_ID'}
# DocumentPart {'type': 'Title'}
# sentence {'id': 'S2.1'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S2.2'}
# DocumentPart {'type': 'SubSectionTitle'}
# sentence {'id': 'S2.3'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.4'}
# xcope {'id': 'X2.4.1'}
# cue {'type': 'speculation', 'ref': 'X2.4.1'}
# sentence {'id': 'S2.5'}
# DocumentPart {'type': 'SubSectionTitle'}
# sentence {'id': 'S2.6'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.7'}
# xcope {'id': 'X2.7.1'}
# cue {'type': 'speculation', 'ref': 'X2.7.1'}
# sentence {'id': 'S2.8'}
# sentence {'id': 'S2.9'}
# sentence {'id': 'S2.10'}
# sentence {'id': 'S2.11'}
# xcope {'id': 'X2.11.1'}
# cue {'type': 'speculation', 'ref': 'X2.11.1'}
# sentence {'id': 'S2.12'}
# sentence {'id': 'S2.13'}
# sentence {'id': 'S2.14'}
# xcope {'id': 'X2.14.1'}
# cue {'type': 'negation', 'ref': 'X2.14.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.15'}
# xcope {'id': 'X2.15.1'}
# cue {'type': 'speculation', 'ref': 'X2.15.1'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.16'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.17'}
# xcope {'id': 'X2.17.1'}
# cue {'type': 'speculation', 'ref': 'X2.17.1'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.18'}
# sentence {'id': 'S2.19'}
# sentence {'id': 'S2.20'}
# xcope {'id': 'X2.20.1'}
# cue {'type': 'speculation', 'ref': 'X2.20.1'}
# sentence {'id': 'S2.21'}
# sentence {'id': 'S2.22'}
# sentence {'id': 'S2.23'}
# xcope {'id': 'X2.23.1'}
# cue {'type': 'speculation', 'ref': 'X2.23.1'}
# sentence {'id': 'S2.24'}
# sentence {'id': 'S2.25'}
# xcope {'id': 'X2.25.1'}
# cue {'type': 'negation', 'ref': 'X2.25.1'}
# sentence {'id': 'S2.26'}
# xcope {'id': 'X2.26.1'}
# cue {'type': 'speculation', 'ref': 'X2.26.1'}
# sentence {'id': 'S2.27'}
# sentence {'id': 'S2.28'}
# xcope {'id': 'X2.28.1'}
# cue {'type': 'speculation', 'ref': 'X2.28.1'}
# sentence {'id': 'S2.29'}
# xcope {'id': 'X2.29.1'}
# cue {'type': 'speculation', 'ref': 'X2.28.1'}
# sentence {'id': 'S2.30'}
# xcope {'id': 'X2.30.1'}
# cue {'type': 'speculation', 'ref': 'X2.31.2'}
# sentence {'id': 'S2.31'}
# sentence {'id': 'S2.32'}
# xcope {'id': 'X2.32.1'}
# cue {'type': 'speculation', 'ref': 'X2.32.1'}
# sentence {'id': 'S2.33'}
# sentence {'id': 'S2.34'}
# sentence {'id': 'S2.36'}
# xcope {'id': 'X2.36.1'}
# cue {'type': 'speculation', 'ref': 'X2.36.1'}
# sentence {'id': 'S2.37'}
# xcope {'id': 'X2.37.1'}
# cue {'type': 'speculation', 'ref': 'X2.37.1'}
# sentence {'id': 'S2.38'}
# xcope {'id': 'X2.38.2'}
# cue {'type': 'negation', 'ref': 'X2.38.2'}
# sentence {'id': 'S2.39'}
# xcope {'id': 'X2.39.1'}
# cue {'type': 'speculation', 'ref': 'X2.39.1'}
# sentence {'id': 'S2.40'}
# xcope {'id': 'X2.40.1'}
# cue {'type': 'speculation', 'ref': 'X2.40.1'}
# sentence {'id': 'S2.41'}
# xcope {'id': 'X2.41.1'}
# cue {'type': 'speculation', 'ref': 'X2.41.1'}
# sentence {'id': 'S2.42'}
# xcope {'id': 'X2.42.1'}
# cue {'type': 'negation', 'ref': 'X2.42.1'}
# sentence {'id': 'S2.43'}
# xcope {'id': 'X2.43.1'}
# cue {'type': 'negation', 'ref': 'X2.43.1'}
# sentence {'id': 'S2.44'}
# sentence {'id': 'S2.45'}
# sentence {'id': 'S2.46'}
# sentence {'id': 'S2.47'}
# sentence {'id': 'S2.48'}
# xcope {'id': 'X2.48.1'}
# cue {'type': 'negation', 'ref': 'X2.48.1'}
# sentence {'id': 'S2.49'}
# xcope {'id': 'X2.49.1'}
# cue {'type': 'speculation', 'ref': 'X2.49.1'}
# sentence {'id': 'S2.50'}
# sentence {'id': 'S2.51'}
# sentence {'id': 'S2.52'}
# sentence {'id': 'S2.53'}
# sentence {'id': 'S2.54'}
# sentence {'id': 'S2.55'}
# sentence {'id': 'S2.56'}
# sentence {'id': 'S2.57'}
# sentence {'id': 'S2.58'}
# sentence {'id': 'S2.59'}
# xcope {'id': 'X2.59.1'}
# cue {'type': 'speculation', 'ref': 'X2.59.1'}
# sentence {'id': 'S2.60'}
# sentence {'id': 'S2.61'}
# xcope {'id': 'X2.61.2'}
# cue {'type': 'speculation', 'ref': 'X2.61.2'}
# DocumentPart {'type': 'Title'}
# sentence {'id': 'S2.63'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.64'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.65'}
# xcope {'id': 'X2.65.2'}
# cue {'type': 'speculation', 'ref': 'X2.65.2'}
# sentence {'id': 'S2.66'}
# sentence {'id': 'S2.67'}
# xcope {'id': 'X2.67.2'}
# cue {'type': 'speculation', 'ref': 'X2.67.2'}
# sentence {'id': 'S2.68'}
# xcope {'id': 'X2.67.2'}
# cue {'type': 'speculation', 'ref': 'X2.67.2'}
# sentence {'id': 'S2.69'}
# xcope {'id': 'X2.69.2'}
# cue {'type': 'speculation', 'ref': 'X2.69.2'}
# sentence {'id': 'S2.70'}
# xcope {'id': 'X2.70.1'}
# cue {'type': 'negation', 'ref': 'X2.70.1'}
# sentence {'id': 'S2.71'}
# xcope {'id': 'X2.71.1'}
# cue {'type': 'speculation', 'ref': 'X2.71.1'}
# sentence {'id': 'S2.72'}
# xcope {'id': 'X2.72.1'}
# cue {'type': 'speculation', 'ref': 'X2.72.1'}
# xcope {'id': 'X2.72.1'}
# cue {'type': 'negation', 'ref': 'X2.72.2'}
# sentence {'id': 'S2.73'}
# xcope {'id': 'X2.73.1'}
# cue {'type': 'negation', 'ref': 'X2.73.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.74'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.75'}
# DocumentPart {'type': 'Title'}
# sentence {'id': 'S2.76'}
# sentence {'id': 'S2.77'}
# sentence {'id': 'S2.78'}
# sentence {'id': 'S2.79'}
# sentence {'id': 'S2.80'}
# sentence {'id': 'S2.81'}
# xcope {'id': 'X2.81.1'}
# cue {'type': 'speculation', 'ref': 'X2.81.1'}
# sentence {'id': 'S2.82'}
# sentence {'id': 'S2.83'}
# sentence {'id': 'S2.84'}
# sentence {'id': 'S2.85'}
# sentence {'id': 'S2.86'}
# sentence {'id': 'S2.87'}
# xcope {'id': 'X2.87.1'}
# cue {'type': 'negation', 'ref': 'X2.87.1'}
# sentence {'id': 'S2.88'}
# sentence {'id': 'S2.89'}
# xcope {'id': 'X2.89.1'}
# cue {'type': 'negation', 'ref': 'X2.89.1'}
# sentence {'id': 'S2.90'}
# xcope {'id': 'X2.90.2'}
# cue {'type': 'speculation', 'ref': 'X2.90.2'}
# sentence {'id': 'S2.91'}
# xcope {'id': 'X2.91.2'}
# cue {'type': 'speculation', 'ref': 'X2.91.2'}
# sentence {'id': 'S2.92'}
# sentence {'id': 'S2.93'}
# xcope {'id': 'X2.93.2'}
# cue {'type': 'speculation', 'ref': 'X2.93.2'}
# sentence {'id': 'S2.95'}
# xcope {'id': 'X2.95.1'}
# cue {'type': 'speculation', 'ref': 'X2.95.1'}
# sentence {'id': 'S2.96'}
# xcope {'id': 'X2.96.1'}
# cue {'type': 'speculation', 'ref': 'X2.96.1'}
# sentence {'id': 'S2.97'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.98'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.99'}
# xcope {'id': 'X2.99.1'}
# cue {'type': 'speculation', 'ref': 'X2.99.1'}
# sentence {'id': 'S2.100'}
# sentence {'id': 'S2.101'}
# xcope {'id': 'X2.101.2'}
# cue {'type': 'speculation', 'ref': 'X2.101.2'}
# sentence {'id': 'S2.102'}
# sentence {'id': 'S2.103'}
# sentence {'id': 'S2.104'}
# sentence {'id': 'S2.105'}
# sentence {'id': 'S2.106'}
# sentence {'id': 'S2.107'}
# sentence {'id': 'S2.108'}
# sentence {'id': 'S2.109'}
# sentence {'id': 'S2.110'}
# sentence {'id': 'S2.111'}
# sentence {'id': 'S2.112'}
# sentence {'id': 'S2.113'}
# DocumentPart {'type': 'مناقشة'}
# sentence {'id': 'S2.114'}
# xcope {'id': 'X2.114.1'}
# cue {'type': 'negation', 'ref': 'X2.114.1'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.115'}
# sentence {'id': 'S2.116'}
# sentence {'id': 'S2.117'}
# sentence {'id': 'S2.118'}
# sentence {'id': 'S2.119'}
# sentence {'id': 'S2.120'}
# sentence {'id': 'S2.121'}
# sentence {'id': 'S2.122'}
# sentence {'id': 'S2.123'}
# sentence {'id': 'S2.124'}
# xcope {'id': 'X2.124.1'}
# cue {'type': 'speculation', 'ref': 'X2.124.1'}
# sentence {'id': 'S2.125'}
# sentence {'id': 'S2.126'}
# sentence {'id': 'S2.127'}
# sentence {'id': 'S2.128'}
# sentence {'id': 'S2.129'}
# sentence {'id': 'S2.130'}
# sentence {'id': 'S2.131'}
# sentence {'id': 'S2.132'}
# sentence {'id': 'S2.133'}
# sentence {'id': 'S2.134'}
# xcope {'id': 'X2.134.1'}
# cue {'type': 'negation', 'ref': 'X2.134.1'}
# sentence {'id': 'S2.135'}
# sentence {'id': 'S2.136'}
# sentence {'id': 'S2.137'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S2.138'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.139'}
# sentence {'id': 'S2.140'}
# xcope {'id': 'X2.140.3'}
# cue {'type': 'negation', 'ref': 'X2.140.3'}
# sentence {'id': 'S2.141'}
# sentence {'id': 'S2.142'}
# sentence {'id': 'S2.143'}
# sentence {'id': 'S2.144'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.145'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S2.146'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.147'}
# sentence {'id': 'S2.148'}
# sentence {'id': 'S2.149'}
# sentence {'id': 'S2.150'}
# xcope {'id': 'X2.150.2'}
# cue {'type': 'speculation', 'ref': 'X2.150.2'}
# sentence {'id': 'S2.151'}
# xcope {'id': 'X2.151.1'}
# cue {'type': 'speculation', 'ref': 'X2.151.1'}
# sentence {'id': 'S2.152'}
# sentence {'id': 'S2.153'}
# sentence {'id': 'S2.154'}
# sentence {'id': 'S2.155'}
# sentence {'id': 'S2.156'}
# sentence {'id': 'S2.157'}
# sentence {'id': 'S2.158'}
# xcope {'id': 'X2.158.2'}
# cue {'type': 'speculation', 'ref': 'X2.158.2'}
# sentence {'id': 'S2.159'}
# sentence {'id': 'S2.160'}
# sentence {'id': 'S2.161'}
# xcope {'id': 'X2.161.2'}
# cue {'type': 'speculation', 'ref': 'X2.161.2'}
# DocumentPart {'type': 'الخلاصة'}
# sentence {'id': 'S2.162'}
# xcope {'id': 'X2.161.2'}
# cue {'type': 'speculation', 'ref': 'X2.161.2'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.163'}
# sentence {'id': 'S2.164'}
# sentence {'id': 'S2.165'}
# DocumentPart {'type': 'Title'}
# sentence {'id': 'S2.174'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.175'}
# sentence {'id': 'S2.176'}
# sentence {'id': 'S2.177'}
# xcope {'id': 'X2.177.2'}
# cue {'type': 'speculation', 'ref': 'X2.177.2'}
# sentence {'id': 'S2.178'}
# sentence {'id': 'S2.179'}
# xcope {'id': 'X2.179.1'}
# cue {'type': 'speculation', 'ref': 'X2.179.1'}
# sentence {'id': 'S2.180'}
# sentence {'id': 'S2.181'}
# sentence {'id': 'S2.182'}
# sentence {'id': 'S2.183'}
# sentence {'id': 'S2.184'}
# sentence {'id': 'S2.185'}
# xcope {'id': 'X2.185.1'}
# cue {'type': 'speculation', 'ref': 'X2.185.1'}
# xcope {'id': 'X2.185.2'}
# cue {'type': 'negation', 'ref': 'X2.185.1'}
# sentence {'id': 'S2.186'}
# sentence {'id': 'S2.187'}
# xcope {'id': 'X2.185.2'}
# cue {'type': 'negation', 'ref': 'X2.185.1'}
# DocumentPart {'type': 'subsection title'}
# sentence {'id': 'S2.189'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.190'}
# sentence {'id': 'S2.191'}
# sentence {'id': 'S2.192'}
# xcope {'id': 'X2.192.3'}
# cue {'type': 'negation', 'ref': 'X2.192.3'}
# sentence {'id': 'S2.193'}
# xcope {'id': 'X2.193.1'}
# cue {'type': 'negation', 'ref': 'X2.193.1'}
# sentence {'id': 'S2.194'}
# sentence {'id': 'S2.195'}
# sentence {'id': 'S2.196'}
# xcope {'id': 'X2.196.1'}
# cue {'type': 'speculation', 'ref': 'X2.196.1'}
# xcope {'id': 'X2.196.1'}
# cue {'type': 'speculation', 'ref': 'X2.196.1'}
# sentence {'id': 'S2.197'}
# sentence {'id': 'S2.198'}
# sentence {'id': 'S2.199'}
# sentence {'id': 'S2.200'}
# sentence {'id': 'S2.201'}
# sentence {'id': 'S2.202'}
# sentence {'id': 'S2.203'}
# sentence {'id': 'S2.204'}
# sentence {'id': 'S2.205'}
# sentence {'id': 'S2.206'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.207'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.208'}
# sentence {'id': 'S2.209'}
# sentence {'id': 'S2.210'}
# sentence {'id': 'S2.211'}
# sentence {'id': 'S2.212'}
# sentence {'id': 'S2.213'}
# sentence {'id': 'S2.214'}
# sentence {'id': 'S2.215'}
# sentence {'id': 'S2.216'}
# sentence {'id': 'S2.217'}
# sentence {'id': 'S2.218'}
# sentence {'id': 'S2.219'}
# sentence {'id': 'S2.220'}
# sentence {'id': 'S2.221'}
# sentence {'id': 'S2.222'}
# sentence {'id': 'S2.223'}
# sentence {'id': 'S2.224'}
# xcope {'id': 'X2.224.1'}
# cue {'type': 'speculation', 'ref': 'X2.224.1'}
# sentence {'id': 'S2.225'}
# DocumentPart {'type': 'section tiltle'}
# sentence {'id': 'S2.226'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.227'}
# sentence {'id': 'S2.228'}
# sentence {'id': 'S2.229'}
# sentence {'id': 'S2.230'}
# sentence {'id': 'S2.231'}
# sentence {'id': 'S2.232'}
# sentence {'id': 'S2.233'}
# sentence {'id': 'S2.234'}
# xcope {'id': 'X2.234.1'}
# cue {'type': 'negation', 'ref': 'X2.234.1'}
# sentence {'id': 'S2.235'}
# sentence {'id': 'S2.236'}
# xcope {'id': 'X2.236.1'}
# cue {'type': 'speculation', 'ref': 'X2.236.1'}
# sentence {'id': 'S2.237'}
# xcope {'id': 'X2.237.1'}
# cue {'type': 'negation', 'ref': 'X2.237.1'}
# sentence {'id': 'S2.238'}
# xcope {'id': 'X2.238.1'}
# cue {'type': 'speculation', 'ref': 'X2.238.1'}
# sentence {'id': 'S2.239'}
# xcope {'id': 'X2.239.2'}
# cue {'type': 'negation', 'ref': 'X2.239.2'}
# sentence {'id': 'S2.240'}
# xcope {'id': 'X2.239.2'}
# cue {'type': 'speculation', 'ref': 'X2.239.2'}
# sentence {'id': 'S2.241'}
# xcope {'id': 'X2.241.2'}
# cue {'type': 'speculation', 'ref': 'X2.241.2'}
# sentence {'id': 'S2.242'}
# xcope {'id': 'X2.242.1'}
# cue {'type': 'negation', 'ref': 'X2.242.1'}
# sentence {'id': 'S2.243'}
# sentence {'id': 'S2.244'}
# sentence {'id': 'S2.245'}
# xcope {'id': 'X2.245.1'}
# cue {'type': 'negation', 'ref': 'X2.245.1'}
# sentence {'id': 'S2.246'}
# sentence {'id': 'S2.249'}
# xcope {'id': 'X2.249.1'}
# cue {'type': 'speculation', 'ref': 'X2.249.2'}
# xcope {'id': 'X2.249.1'}
# cue {'type': 'speculation', 'ref': 'X2.249.2'}
# DocumentPart {'type': 'section title'}
# sentence {'id': 'S2.250'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.251'}
# xcope {'id': 'X2.249.1'}
# cue {'type': 'speculation', 'ref': 'X2.249.1'}
# xcope {'id': 'X2.249.2'}
# cue {'type': 'negation', 'ref': 'X2.249.2'}
# sentence {'id': 'S2.252'}
# sentence {'id': 'S2.253'}
# sentence {'id': 'S2.254'}
# sentence {'id': 'S2.255'}
# sentence {'id': 'S2.256'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S2.257'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.258'}
# sentence {'id': 'S2.259'}
# sentence {'id': 'S2.260'}
# sentence {'id': 'S2.261'}
# xcope {'id': 'X2.261.1'}
# cue {'type': 'speculation', 'ref': 'X2.261.1'}
# sentence {'id': 'S2.262'}
# sentence {'id': 'S2.263'}
# sentence {'id': 'S2.264'}
# xcope {'id': 'X2.264.1'}
# cue {'type': 'speculation', 'ref': 'X2.264.1'}
# sentence {'id': 'S2.265'}
# sentence {'id': 'S2.266'}
# sentence {'id': 'S2.269'}
# xcope {'id': 'X2.269.1'}
# cue {'type': 'speculation', 'ref': 'X2.269.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.270'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.271'}
# sentence {'id': 'S2.272'}
# sentence {'id': 'S2.273'}
# sentence {'id': 'S2.274'}
# sentence {'id': 'S2.275'}
# sentence {'id': 'إذا توجد زمر دموية ونسيجية في الوقت نفسه مثل زمرة\r\n.Rh فقط مثل زمرة'}
# sentence {'id': 'S2.277'}
# sentence {'id': 'S2.278'}
# xcope {'id': 'X2.278.2'}
# cue {'type': 'speculation', 'ref': 'X2.278.2'}
# sentence {'id': 'S2.279'}
# xcope {'id': 'X2.279.3'}
# cue {'type': 'speculation', 'ref': 'X2.279.3'}
# sentence {'id': 'S2.280'}
# sentence {'id': 'S2.281'}
# sentence {'id': 'S2.282'}
# sentence {'id': 'S2.283'}
# sentence {'id': 'S2.284'}
# xcope {'id': 'X2.284.2'}
# cue {'type': 'speculation', 'ref': 'X2.284.2'}
# xcope {'id': 'X2.284.1'}
# cue {'type': 'speculation', 'ref': 'X2.284.1'}
# sentence {'id': 'S2.285'}
# sentence {'id': 'S2.286'}
# sentence {'id': 'S2.287'}
# xcope {'id': 'X2.287.1'}
# cue {'type': 'negation', 'ref': 'X2.287.1'}
# sentence {'id': 'S2.288'}
# xcope {'id': 'X2.288.2'}
# cue {'type': 'negation', 'ref': 'X2.288.2'}
# xcope {'id': 'X2.288.1'}
# cue {'type': 'negation', 'ref': 'X2.288.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.289'}
# xcope {'id': 'X2.289.1'}
# cue {'type': 'speculation', 'ref': 'X2.289.1'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.290'}
# xcope {'id': 'X2.290.1'}
# cue {'type': 'speculation', 'ref': 'X2.290.1'}
# sentence {'id': 'S2.291'}
# sentence {'id': 'S2.292'}
# sentence {'id': 'S2.293'}
# sentence {'id': 'S2.294'}
# xcope {'id': 'X2.294.2'}
# cue {'type': 'negation', 'ref': 'X2.294.2'}
# sentence {'id': 'S2.295'}
# xcope {'id': 'X2.295.1'}
# cue {'type': 'speculation', 'ref': 'X2.294.1'}
# xcope {'id': 'X2.295.2'}
# cue {'type': 'negation', 'ref': 'X2.295.2'}
# sentence {'id': 'S2.296'}
# sentence {'id': 'S2.297'}
# sentence {'id': 'S2.298'}
# xcope {'id': 'X2.298.1'}
# cue {'type': 'speculation', 'ref': 'X2.298.1'}
# sentence {'id': 'S2.299'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S2.300'}
# xcope {'id': 'X2.300.1'}
# cue {'type': 'negation', 'ref': 'X2.300.1'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.301'}
# xcope {'id': 'X2.301.1'}
# cue {'type': 'speculation', 'ref': 'X2.301.1'}
# sentence {'id': 'S2.302'}
# xcope {'id': 'X2.301.1'}
# cue {'type': 'speculation', 'ref': 'X2.301.1'}
# sentence {'id': 'S2.303'}
# sentence {'id': 'S2.304'}
# xcope {'id': 'X2.304.1'}
# cue {'type': 'negation', 'ref': 'X2.304.1'}
# sentence {'id': 'S2.305'}
# sentence {'id': 'S2.306'}
# sentence {'id': 'S2.307'}
# sentence {'id': 'S2.308'}
# sentence {'id': 'S2.309'}
# sentence {'id': 'S2.310'}
# sentence {'id': 'S2.311'}
# sentence {'id': 'S2.312'}
# xcope {'id': 'X2.312.1'}
# cue {'type': 'negation', 'ref': 'X2.312.1'}
# sentence {'id': 'S2.313'}
# xcope {'id': 'X2.313.1'}
# cue {'type': 'negation', 'ref': 'X2.313.1'}
# sentence {'id': 'S2.314'}
# sentence {'id': 'S2.315'}
# DocumentPart {'type': 'Title'}
# sentence {'id': 'S2.316'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S2.318'}
# sentence {'id': 'S2.319'}
# xcope {'id': 'X2.319.1'}
# cue {'type': 'speculation', 'ref': 'X2.319.1'}
# sentence {'id': 'S2.320'}
# xcope {'id': 'X2.320.1'}
# cue {'type': 'speculation', 'ref': 'X2.320.1'}
# sentence {'id': 'S2.321'}
# sentence {'id': 'S2.322'}
# sentence {'id': 'S2.323'}
# xcope {'id': 'X2.323.1'}
# cue {'type': 'speculation', 'ref': 'X2.323.1'}
# sentence {'id': 'S2.324'}
# sentence {'id': 'S2.325'}
# sentence {'id': 'S2.326'}
# DocumentPart {}
# DocumentsC {'type': 'biomedical articles'}
# DocID {'type': 'BMC_ID'}
# DocumentPart {'type': 'Title'}
# sentence {'id': 'S3.1'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S3.2'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.3'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.4'}
# DocumentPart {'type': 'SubSectionTitle'}
# sentence {'id': 'S3.5'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.6'}
# xcope {'id': 'X3.6.1'}
# cue {'type': 'speculation', 'ref': 'X3.6.1'}
# sentence {'id': 'S3.7'}
# sentence {'id': 'S3.8'}
# sentence {'id': 'S3.9'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.10'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.11'}
# sentence {'id': 'S3.12'}
# xcope {'id': 'X3.12.1'}
# cue {'type': 'negation', 'ref': 'X3.12.1'}
# sentence {'id': 'S3.13'}
# xcope {'id': 'X3.13.1'}
# cue {'type': 'speculation', 'ref': 'X3.13.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.14'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.15'}
# sentence {'id': 'S3.16'}
# sentence {'id': 'S3.17'}
# sentence {'id': 'S3.18'}
# sentence {'id': 'S3.19'}
# sentence {'id': 'S3.20'}
# sentence {'id': 'S3.21'}
# sentence {'id': 'S3.22'}
# sentence {'id': 'S3.23'}
# sentence {'id': 'S3.24'}
# sentence {'id': 'S3.25'}
# xcope {'id': 'X3.25.1'}
# cue {'type': 'speculation', 'ref': 'X3.25.1'}
# sentence {'id': 'S3.26'}
# sentence {'id': 'S3.27'}
# sentence {'id': 'S3.28'}
# sentence {'id': 'S3.29'}
# sentence {'id': 'S3.30'}
# sentence {'id': 'S3.31'}
# sentence {'id': 'S3.32'}
# sentence {'id': 'S3.33'}
# sentence {'id': 'S3.34'}
# sentence {'id': 'S3.35'}
# sentence {'id': 'S3.36'}
# sentence {'id': 'S3.37'}
# sentence {'id': 'S3.38'}
# xcope {'id': 'X3.38.2'}
# cue {'type': 'speculation', 'ref': 'X3.38.2'}
# xcope {'id': 'X3.38.1'}
# cue {'type': 'speculation', 'ref': 'X3.38.1'}
# sentence {'id': 'S3.39'}
# sentence {'id': 'S3.40'}
# sentence {'id': 'S3.41'}
# sentence {'id': 'S3.42'}
# xcope {'id': 'X3.42.2'}
# xcope {'id': 'X3.42.1'}
# cue {'type': 'speculation', 'ref': 'X3.42.1'}
# sentence {'id': 'S3.43'}
# sentence {'id': 'S3.51'}
# xcope {'id': 'X3.51.1'}
# cue {'type': 'speculation', 'ref': 'X3.51.1'}
# sentence {'id': 'S3.52'}
# sentence {'id': 'S3.54'}
# xcope {'id': 'X3.54.1'}
# cue {'type': 'speculation', 'ref': 'X3.54.1'}
# sentence {'id': 'S3.55'}
# xcope {'id': 'X3.54.1'}
# cue {'type': 'speculation', 'ref': 'X3.54.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.56'}
# DocumentPart {}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.58'}
# xcope {'id': 'X3.58.1'}
# cue {'type': 'speculation', 'ref': 'X3.58.1'}
# sentence {'id': 'S3.59'}
# sentence {'id': 'S3.62'}
# xcope {'id': 'X3.62.2'}
# cue {'type': 'speculation', 'ref': 'X3.62.2'}
# sentence {'id': 'S3.63'}
# sentence {'id': 'S3.64'}
# DocumentPart {'type': 'Figure'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.72'}
# xcope {'id': 'X3.72.1'}
# cue {'type': 'speculation', 'ref': 'X3.72.1'}
# sentence {'id': 'S3.73'}
# sentence {'id': 'S3.74'}
# sentence {'id': 'S3.80'}
# xcope {'id': 'X3.80.1'}
# xcope {'id': 'X3.80.2'}
# cue {'type': 'speculation', 'ref': 'X3.80.2'}
# sentence {'id': 'S3.81'}
# xcope {'id': 'X3.81.1'}
# cue {'type': 'speculation', 'ref': 'X3.81.1'}
# sentence {'id': 'S3.89'}
# sentence {'id': 'S3.90'}
# xcope {'id': 'X3.90.1'}
# cue {'type': 'negation', 'ref': 'X3.90.1'}
# sentence {'id': 'S3.91'}
# xcope {'id': 'X3.91.1'}
# cue {'type': 'speculation', 'ref': 'X3.91.1'}
# xcope {'id': 'X3.90.1'}
# cue {'type': 'negation', 'ref': 'X3.90.1'}
# DocumentPart {'type': ''}
# DocumentPart {}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.98'}
# xcope {'id': 'X3.98.1'}
# cue {'type': 'speculation', 'ref': 'X3.98.1'}
# sentence {'id': 'S3.99'}
# xcope {'id': 'X3.99.1'}
# cue {'type': 'speculation', 'ref': 'X3.99.1'}
# sentence {'id': 'S3.100'}
# xcope {'id': 'X3.100.1'}
# cue {'type': 'speculation', 'ref': 'X3.100.1'}
# xcope {'id': 'X3.100.2'}
# cue {'type': 'negation', 'ref': 'X3.100.2'}
# sentence {'id': 'S3.101'}
# sentence {'id': 'S3.102'}
# xcope {'id': 'X3.102.1'}
# cue {'type': 'speculation', 'ref': 'X3.102.1'}
# sentence {'id': 'S3.103'}
# xcope {'id': 'X3.103.1'}
# cue {'type': 'speculation', 'ref': 'X3.103.1'}
# sentence {'id': 'S3.104'}
# xcope {'id': 'X3.104.1'}
# cue {'type': 'speculation', 'ref': 'X3.104.1'}
# sentence {'id': 'S3.105'}
# DocumentPart {'type': ''}
# DocumentPart {'type': 'Text'}
# sentence {}
# sentence {'id': 'S3.109'}
# xcope {'id': 'X3.109.1'}
# cue {'type': 'speculation', 'ref': 'X3.109.1'}
# sentence {'id': 'S3.110'}
# xcope {'id': 'X3.110.1'}
# cue {'type': 'speculation', 'ref': 'X3.110.1'}
# sentence {'id': 'S3.111'}
# sentence {'id': 'S3.112'}
# xcope {'id': 'X3.112.1'}
# cue {'type': 'speculation', 'ref': 'X3.112.1'}
# sentence {'id': 'S3.113'}
# xcope {'id': 'X3.113.1'}
# cue {'type': 'speculation', 'ref': 'X3.113.1'}
# sentence {'id': 'S3.114'}
# sentence {'id': 'S3.115'}
# sentence {'id': 'S3.116'}
# xcope {'id': 'X3.113.1'}
# cue {'type': 'speculation', 'ref': 'X3.113.1'}
# sentence {'id': 'S3.117'}
# xcope {'id': 'X3.117.2'}
# cue {'type': 'speculation', 'ref': 'X3.117.2'}
# sentence {'id': 'S3.118'}
# sentence {'id': 'S3.119'}
# xcope {'id': 'X3.119.1'}
# cue {'type': 'speculation', 'ref': 'X3.119.1'}
# sentence {'id': 'S3.120'}
# sentence {'id': 'S3.121'}
# xcope {'id': 'X3.121.1'}
# cue {'type': 'speculation', 'ref': 'X3.121.1'}
# sentence {'id': 'S3.122'}
# xcope {'id': 'X3.122.2'}
# cue {'type': 'speculation', 'ref': 'X3.122.2'}
# sentence {'id': 'S3.123'}
# sentence {'id': 'S3.124'}
# xcope {'id': 'X3.124.1'}
# cue {'type': 'speculation', 'ref': 'X3.124.1'}
# DocumentPart {'type': 'خلاصة'}
# sentence {'id': 'S3.125'}
# xcope {'id': 'X3.124.1'}
# cue {'type': 'speculation', 'ref': 'X3.124.1'}
# xcope {'id': 'X3.124.2'}
# cue {'type': 'negation', 'ref': 'X3.124.2'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.126'}
# sentence {'id': 'S3.127'}
# DocumentPart {'type': 'title'}
# sentence {'id': 'S3.128'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.129'}
# sentence {'id': 'S3.130'}
# sentence {'id': 'S3.131'}
# sentence {'id': 'S3.132'}
# sentence {'id': 'S3.133'}
# xcope {'id': 'X3.133.1'}
# cue {'type': 'negation', 'ref': 'X3.133.1'}
# xcope {'id': 'X3.133.1'}
# cue {'type': 'speculation', 'ref': 'X3.133.1'}
# sentence {'id': 'S3.134'}
# sentence {'id': 'S3.135'}
# sentence {'id': 'S3.136'}
# sentence {'id': 'S3.137'}
# sentence {'id': 'S3.138'}
# sentence {'id': 'S3.139'}
# xcope {'id': 'X3.139.1'}
# cue {'type': 'speculation', 'ref': 'X3.139.1'}
# sentence {'id': 'S3.140'}
# sentence {'id': 'S3.141'}
# sentence {'id': 'S3.142'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.143'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.144'}
# sentence {'id': 'S3.145'}
# sentence {'id': 'S3.146'}
# xcope {'id': 'X3.146.1'}
# cue {'type': 'negation', 'ref': 'X3.146.1'}
# sentence {'id': 'S3.147'}
# sentence {'id': 'S3.148'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.150'}
# sentence {'id': 'S3.151'}
# sentence {'id': 'S3.152'}
# xcope {'id': 'X3.152.1'}
# cue {'type': 'speculation', 'ref': 'X3.152.1'}
# sentence {'id': 'S3.153'}
# sentence {'id': 'S3.154'}
# sentence {'id': 'S3.155'}
# sentence {'id': 'S3.156'}
# sentence {'id': 'S3.157'}
# xcope {'id': 'X3.157.2'}
# cue {'type': 'speculation', 'ref': 'X3.157.2'}
# sentence {'id': 'S3.158'}
# xcope {'id': 'X3.158.1'}
# cue {'type': 'speculation', 'ref': 'X3.158.1'}
# sentence {'id': 'S3.159'}
# sentence {'id': 'S3.160'}
# xcope {'id': 'X3.160.1'}
# cue {'type': 'speculation', 'ref': 'X3.160.1'}
# DocumentPart {'type': 'SubSectionTitle'}
# sentence {'id': 'S3.161'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.162'}
# sentence {'id': 'S3.163'}
# sentence {'id': 'S3.164'}
# sentence {'id': 'S3.165'}
# xcope {'id': 'X3.165.1'}
# cue {'type': 'negation', 'ref': 'X3.165.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.166'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.167'}
# sentence {'id': 'S3.168'}
# sentence {'id': 'S3.172'}
# xcope {'id': 'X3.172.1'}
# cue {'type': 'negation', 'ref': 'X3.172.1'}
# sentence {'id': 'S3.173'}
# sentence {'id': 'S3.174'}
# xcope {'id': 'X3.174.1'}
# cue {'type': 'negation', 'ref': 'X3.174.1'}
# sentence {'id': 'S3.175'}
# xcope {'id': 'X3.175.1'}
# cue {'type': 'negation', 'ref': 'X3.175.1'}
# sentence {'id': 'S3.176'}
# sentence {'id': 'S3.177'}
# xcope {'id': 'X3.177.1'}
# cue {'type': 'negation', 'ref': 'X3.177.1'}
# xcope {'id': 'X3.177.2'}
# cue {'type': 'speculation', 'ref': 'X3.177.1'}
# sentence {'id': 'S3.178'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.179'}
# xcope {'id': 'X3.179.1'}
# cue {'type': 'negation', 'ref': 'X3.179.1'}
# xcope {'id': 'X3.179.2'}
# cue {'type': 'speculation', 'ref': 'X3.179.2'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.180'}
# xcope {'id': 'X3.180.1'}
# cue {'type': 'negation', 'ref': 'X3.180.1'}
# sentence {'id': 'S3.181'}
# xcope {'id': 'X3.181.1'}
# cue {'type': 'speculation', 'ref': 'X3.181.1'}
# sentence {'id': 'S3.182'}
# xcope {'id': 'X3.182.1'}
# cue {'type': 'speculation', 'ref': 'X3.182.1'}
# xcope {'id': 'X3.182.2'}
# cue {'type': 'negation', 'ref': 'X3.182.2'}
# sentence {'id': 'S3.183'}
# xcope {'id': 'X3.183.1'}
# cue {'type': 'negation', 'ref': 'X3.183.1'}
# sentence {'id': 'S3.184'}
# xcope {'id': 'X3.184.1'}
# cue {'type': 'negation', 'ref': 'X3.184.1'}
# sentence {'id': 'S3.185'}
# sentence {'id': 'S3.186'}
# xcope {'id': 'X3.186.1'}
# cue {'type': 'speculation', 'ref': 'X3.186.1'}
# sentence {'id': 'S3.187'}
# xcope {'id': 'X3.187.1'}
# cue {'type': 'speculation', 'ref': 'X3.187.1'}
# sentence {'id': 'S3.190'}
# xcope {'id': 'X3.190.1'}
# cue {'type': 'negation', 'ref': 'X3.190.1'}
# xcope {'id': 'X3.190.2'}
# cue {'type': 'speculation', 'ref': 'X3.190.2'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.191'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.192'}
# sentence {'id': 'S3.193'}
# xcope {'id': 'X3.193.1'}
# cue {'type': 'negation', 'ref': 'X3.193.1'}
# sentence {'id': 'S3.195'}
# DocumentPart {'type': 'SubSectionTitle'}
# sentence {'id': 'S3.196'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.197'}
# sentence {'id': 'S3.198'}
# sentence {'id': 'S3.199'}
# sentence {'id': 'S3.200'}
# sentence {'id': 'S3.201'}
# sentence {'id': 'S3.203'}
# sentence {'id': 'S3.204'}
# sentence {'id': 'S3.205'}
# sentence {'id': 'S3.206'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.207'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.208'}
# sentence {'id': 'S3.209'}
# sentence {'id': 'S3.210'}
# sentence {'id': 'S3.211'}
# sentence {'id': 'S3.212'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.213'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.215'}
# xcope {'id': 'X3.215.1'}
# cue {'type': 'negation', 'ref': 'X3.215.1'}
# sentence {'id': 'S3.216'}
# sentence {'id': 'S3.217'}
# sentence {'id': 'S3.218'}
# sentence {'id': 'S3.219'}
# sentence {'id': 'S3.220'}
# sentence {'id': 'S3.221'}
# sentence {'id': 'S3.222'}
# sentence {'id': 'S3.226'}
# sentence {'id': 'S3.227'}
# sentence {'id': 'S3.228'}
# sentence {'id': 'S3.229'}
# xcope {'id': 'X3.229.3'}
# cue {'type': 'speculation', 'ref': 'X3.229.3'}
# sentence {'id': 'S3.230'}
# sentence {'id': 'S3.231'}
# sentence {'id': 'S3.232'}
# sentence {'id': 'S3.233'}
# sentence {'id': 'S3.234'}
# sentence {'id': 'S3.235'}
# sentence {'id': 'S3.237'}
# sentence {'id': 'S3.238'}
# xcope {'id': 'X3.239.1'}
# cue {'type': 'negation', 'ref': 'X3.239.1'}
# sentence {'id': 'S3.239'}
# sentence {'id': 'S3.240'}
# sentence {'id': 'S3.242'}
# sentence {'id': 'S3.243'}
# sentence {'id': 'S3.244'}
# sentence {'id': 'S3.245'}
# sentence {'id': 'S3.246'}
# sentence {'id': 'S3.247'}
# sentence {'id': 'S3.248'}
# sentence {'id': 'S3.249'}
# sentence {'id': 'S3.250'}
# sentence {'id': 'S3.251'}
# sentence {'id': 'S3.252'}
# sentence {'id': 'S3.253'}
# sentence {'id': 'S3.254'}
# sentence {'id': 'S3.255'}
# sentence {'id': 'S3.256'}
# sentence {'id': 'S3.257'}
# sentence {'id': 'S3.258'}
# sentence {'id': 'S3.259'}
# xcope {'id': 'X3.259.1'}
# cue {'type': 'speculation', 'ref': 'X3.259.1'}
# sentence {'id': 'S3.260'}
# sentence {'id': 'S3.261'}
# sentence {'id': 'S3.262'}
# sentence {'id': 'S3.263'}
# sentence {'id': 'S3.264'}
# xcope {'id': 'X3.263.2'}
# cue {'type': 'speculation', 'ref': 'X3.263.2'}
# sentence {'id': 'S3.265'}
# sentence {'id': 'S3.266'}
# sentence {'id': 'S3.267'}
# sentence {'id': 'S3.268'}
# xcope {'id': 'X3.268.1'}
# cue {'type': 'negation', 'ref': 'X3.268.1'}
# sentence {'id': 'S3.269'}
# xcope {'id': 'X3.269.1'}
# cue {'type': 'negation', 'ref': 'X3.269.1'}
# sentence {'id': 'S3.270'}
# xcope {'id': 'X3.270.2'}
# cue {'type': 'speculation', 'ref': 'X3.270.2'}
# sentence {'id': 'S3.271'}
# xcope {'id': 'X3.273.1'}
# cue {'type': 'negation', 'ref': 'X3.273.1'}
# sentence {'id': 'S3.272'}
# xcope {'id': 'X3.273.2'}
# cue {'type': 'speculation', 'ref': 'X3.273.2'}
# sentence {'id': 'S3.273'}
# DocumentPart {'type': 'Title'}
# sentence {'id': 'S3.274'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.275'}
# xcope {'id': 'X3.275.1'}
# cue {'type': 'speculation', 'ref': 'X3.275.1'}
# sentence {'id': 'S3.276'}
# sentence {'id': 'S3.277'}
# xcope {'id': 'X3.277.1'}
# cue {'type': 'speculation', 'ref': 'X3.277.1'}
# sentence {'id': 'S3.278'}
# sentence {'id': 'S3.279'}
# xcope {'id': 'X3.279.1'}
# cue {'type': 'speculation', 'ref': 'X3.279.1'}
# xcope {'id': 'X3.279.2'}
# cue {'type': 'negation', 'ref': 'X3.279.2'}
# sentence {'id': 'S3.280'}
# xcope {'id': 'X3.279.1'}
# cue {'type': 'speculation', 'ref': 'X3.279.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.281'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.282'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.283'}
# sentence {'id': 'S3.284'}
# sentence {'id': 'S3.285'}
# sentence {'id': 'S3.286'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S3.292'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.293'}
# sentence {'id': 'S3.294'}
# sentence {'id': 'S3.295'}
# sentence {'id': 'S3.296'}
# sentence {'id': 'S3.297'}
# xcope {'id': 'X3.294.1'}
# cue {'type': 'negation', 'ref': 'X3.294.1'}
# DocumentPart {'type': ''}
# sentence {'id': 'S3.298'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.299'}
# sentence {'id': 'S3.300'}
# sentence {'id': 'S3.301'}
# sentence {'id': 'S3.302'}
# sentence {'id': 'S3.303'}
# xcope {'id': 'X3.303.1'}
# cue {'type': 'speculation', 'ref': 'X3.303.1'}
# DocumentPart {'type': 'SubSectionTitle'}
# sentence {'id': 'S3.304'}
# sentence {'id': 'S3.305'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.306'}
# sentence {'id': 'S3.307'}
# xcope {'id': 'X3.307.2'}
# cue {'type': 'speculation', 'ref': 'X3.307.2'}
# xcope {'id': 'X3.307.1'}
# cue {'type': 'speculation', 'ref': 'X3.307.1'}
# DocumentPart {}
# sentence {'id': 'S3.308'}
# xcope {'id': 'X3.307.1'}
# cue {'type': 'speculation', 'ref': 'X3.307.1'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.309'}
# sentence {'id': 'S3.310'}
# sentence {'id': 'S3.311'}
# xcope {'id': 'X3.307.1'}
# cue {'type': 'negation', 'ref': 'X3.307.1'}
# sentence {'id': 'S3.312'}
# sentence {'id': 'S3.314'}
# sentence {'id': 'S3.315'}
# sentence {'id': 'S3.316'}
# sentence {'id': 'S3.317'}
# sentence {'id': 'S3.318'}
# sentence {'id': 'S3.319'}
# sentence {'id': 'S3.320'}
# sentence {'id': 'S3.321'}
# xcope {'id': 'X3.321.2'}
# cue {'type': 'negation', 'ref': 'X3.321.2'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S3.322'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.323'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S3.324'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S3.325'}
# sentence {'id': 'S3.326'}
# sentence {'id': 'S3.327'}
# sentence {'id': 'S3.328'}
# sentence {'id': 'S3.329'}
# sentence {'id': 'S3.330'}
# sentence {'id': 'S3.331'}
# xcope {'id': 'X3.331.1'}
# cue {'type': 'speculation', 'ref': 'X3.331.1'}
# sentence {'id': 'S3.332'}
# xcope {'id': 'X3.332.1'}
# cue {'type': 'speculation', 'ref': 'X3.332.1'}
# DocumentsD {'type': 'biomedical articles'}
# DocID {'type': 'BMC_ID'}
# DocumentPart {'type': 'SECTION Title'}
# sentence {'id': 'S4.1'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S4.2'}
# DocumentPart {'type': 'SubSectionTitle'}
# sentence {}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.4'}
# sentence {'id': 'S4.5'}
# sentence {'id': 'S4.6'}
# DocumentPart {'type': 'TEXT'}
# sentence {'id': 'S4.7'}
# xcope {'id': 'X4.7.1'}
# cue {'type': 'speculation', 'ref': 'X4.7.1'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.8'}
# xcope {'id': 'X4.8.1'}
# cue {'type': 'negation', 'ref': 'X4.8.1'}
# xcope {'id': 'X4.8.2'}
# cue {'type': 'speculation', 'ref': 'X4.8.2'}
# xcope {'id': 'X4.8.3'}
# cue {'type': 'speculation', 'ref': 'X4.8.3'}
# sentence {'id': 'S4.9'}
# sentence {'id': 'S4.10'}
# sentence {'id': 'S4.11'}
# xcope {'id': 'X4.11.1'}
# cue {'type': 'negation', 'ref': 'X4.11.1'}
# sentence {'id': 'S4.12'}
# sentence {'id': 'S4.13'}
# xcope {'id': 'X4.13.1'}
# cue {'type': 'speculation', 'ref': 'X4.13.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S4.14'}
# DocumentPart {'type': 'Text'}
# sentence {}
# sentence {'id': 'S4.19'}
# xcope {'id': 'X4.19.1'}
# cue {'type': 'negation', 'ref': 'X4.19.1'}
# sentence {'id': 'S4.20'}
# xcope {'id': 'X4.20.1'}
# cue {'type': 'negation', 'ref': 'X4.20.1'}
# xcope {'id': 'X4.20.1'}
# cue {'type': 'negation', 'ref': 'X4.20.1'}
# sentence {'id': 'S4.21'}
# sentence {'id': 'S4.22'}
# sentence {'id': 'S4.23'}
# xcope {'id': 'X4.23.2'}
# cue {'type': 'speculation', 'ref': 'X4.23.2'}
# sentence {'id': 'S4.24'}
# xcope {'id': 'X4.24.1'}
# cue {'type': 'speculation', 'ref': 'X4.24.1'}
# sentence {'id': 'S4.25'}
# sentence {}
# sentence {'id': 'S4.27'}
# sentence {'id': 'S4.30'}
# xcope {'id': 'X4.30.2'}
# cue {'type': 'negation', 'ref': 'X4.30.2'}
# sentence {'id': 'S4.32'}
# xcope {'id': 'X4.32.1'}
# cue {'type': 'speculation', 'ref': 'X4.32.1'}
# sentence {'id': 'S4.33'}
# sentence {'id': 'S4.36'}
# xcope {'id': 'X4.36.1'}
# cue {'type': 'speculation', 'ref': 'X4.36.1'}
# xcope {'id': 'X4.36.1'}
# cue {'type': 'speculation', 'ref': 'X4.36.1'}
# sentence {'id': 'S4.37'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S4.38'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S4.39'}
# DocumentPart {'type': 'title'}
# sentence {'id': 'S4.40'}
# sentence {'id': 'S4.41'}
# sentence {'id': 'S4.42'}
# sentence {'id': 'S4.43'}
# sentence {'id': 'S4.44'}
# sentence {'id': 'S4.45'}
# sentence {'id': 'S4.46'}
# sentence {'id': 'S4.47'}
# sentence {'id': 'S4.48'}
# sentence {'id': 'S4.49'}
# xcope {'id': 'X4.49.1'}
# cue {'type': 'negation', 'ref': 'X4.49.1'}
# xcope {'id': 'X4.49.2'}
# cue {'type': 'negation', 'ref': 'X4.49.2'}
# DocumentPart {'type': 'sectiontitle'}
# sentence {'id': 'S4.50'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.51'}
# xcope {'id': 'X4.51.1'}
# cue {'type': 'speculation', 'ref': 'X4.51.1'}
# sentence {'id': 'S4.52'}
# sentence {'id': 'S4.53'}
# DocumentPart {'type': 'TEXT'}
# sentence {'id': 'S4.54'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.55'}
# sentence {'id': 'S4.57'}
# sentence {'id': 'S4.58'}
# xcope {'id': 'X4.58.1'}
# cue {'type': 'speculation', 'ref': 'X4.58.1'}
# sentence {'id': 'S4.59'}
# xcope {'id': 'X4.59.3'}
# cue {'type': '', 'ref': 'speculation'}
# sentence {'id': 'S4.60'}
# sentence {'id': 'S4.61'}
# sentence {'id': 'S4.63'}
# xcope {'id': 'X4.63.1'}
# cue {'type': 'negation', 'ref': 'X4.63.1'}
# xcope {'id': 'X4.63.1'}
# cue {'type': 'negation', 'ref': 'X4.63.1'}
# sentence {'id': 'S4.64'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S4.65'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.66'}
# sentence {'id': 'S4.67'}
# sentence {'id': 'S4.68'}
# sentence {'id': 'S4.69'}
# sentence {'id': 'S4.70'}
# sentence {'id': 'S4.71'}
# DocumentPart {'type': 'sectiontitle'}
# sentence {'id': 'S4.72'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.73'}
# sentence {'id': 'S4.74'}
# sentence {'id': 'S4.75'}
# sentence {'id': 'S4.76'}
# sentence {'id': 'S4.77'}
# sentence {'id': 'S4.78'}
# sentence {'id': 'S4.79'}
# sentence {'id': 'S4.80'}
# sentence {'id': 'S4.81'}
# sentence {'id': 'S4.82'}
# sentence {'id': 'S4.83'}
# sentence {'id': 'S4.84'}
# sentence {'id': 'S4.85'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S4.86'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.87'}
# sentence {'id': 'S4.88'}
# sentence {'id': 'S4.89'}
# sentence {'id': 'S4.90'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S4.91'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.92'}
# sentence {'id': 'S4.93'}
# sentence {'id': 'S4.94'}
# sentence {'id': 'S4.95'}
# sentence {'id': 'S4.96'}
# sentence {'id': 'S4.97'}
# sentence {'id': 'S4.98'}
# sentence {'id': 'S4.99'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S4.100'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.101'}
# sentence {'id': 'S4.103'}
# sentence {'id': 'S4.104'}
# xcope {'id': 'X4.104.1'}
# cue {'type': 'speculation', 'ref': 'X4.104.1'}
# sentence {'id': 'S4.105'}
# sentence {'id': 'S4.106'}
# sentence {'id': 'S4.107'}
# sentence {'id': 'S4.108'}
# sentence {'id': 'S4.109'}
# xcope {'id': 'X4.104.1'}
# cue {'type': 'negation', 'ref': 'X4.104.1'}
# sentence {'id': 'S4.110'}
# xcope {'id': 'X4.110.3'}
# cue {'type': 'negation', 'ref': 'X4.110.3'}
# sentence {}
# xcope {'id': 'X4.112.1'}
# cue {'type': 'negation', 'ref': 'X4.112.1'}
# sentence {'id': 'S4.112'}
# sentence {'id': 'S4.113'}
# sentence {'id': 'S4.114'}
# sentence {'id': 'S4.115'}
# sentence {'id': 'S4.116'}
# xcope {'id': 'X4.116.1'}
# cue {'type': 'speculation', 'ref': 'X4.116.1'}
# sentence {'id': 'S4.117'}
# sentence {'id': 'S4.118'}
# sentence {'id': 'S4.119'}
# sentence {'id': 'S4.120'}
# xcope {'id': 'X4.120.2'}
# cue {'type': 'negation', 'ref': 'X4.120.2'}
# DocumentPart {'type': ''}
# sentence {'id': 'S4.121'}
# xcope {'id': 'X4.121.2'}
# cue {'type': 'negation', 'ref': 'X4.121.2'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.122'}
# xcope {'id': 'X4.122.1'}
# cue {'type': 'negation', 'ref': 'X4.122.1'}
# sentence {'id': 'S4.123'}
# xcope {'id': 'X4.123.1'}
# cue {'type': 'negation', 'ref': 'X4.123.1'}
# sentence {'id': 'S4.124'}
# sentence {'id': 'S4.125'}
# xcope {'id': 'X4.125.1'}
# cue {'type': 'speculation', 'ref': 'X4.125.1'}
# xcope {'id': 'X4.125.2'}
# cue {'type': 'speculation', 'ref': 'X4.125.2'}
# sentence {'id': 'S4.126'}
# xcope {'id': 'X4.125.1'}
# cue {'type': 'negation', 'ref': 'X4.125.1'}
# sentence {'id': 'S4.127'}
# sentence {'id': 'S4.128'}
# sentence {'id': 'S4.129'}
# xcope {'id': 'X4.129.1'}
# cue {'type': 'negation', 'ref': 'X4.129.1'}
# sentence {'id': 'S4.130'}
# xcope {'id': 'X4.130.1'}
# cue {'type': 'negation', 'ref': 'X4.130.1'}
# sentence {'id': 'S4.131'}
# sentence {'id': 'S4.132'}
# xcope {'id': 'X4.132.1'}
# cue {'type': 'negation', 'ref': 'X4.132.1'}
# xcope {'id': 'X4.132.2'}
# cue {'type': 'speculation', 'ref': 'X4.132.2'}
# xcope {'id': 'X4.132.3'}
# cue {'type': 'speculation', 'ref': 'X4.132.3'}
# DocumentPart {'type': 'Title'}
# sentence {'id': 'S4.201'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.202'}
# sentence {'id': 'S4.203'}
# sentence {'id': 'S4.204'}
# xcope {'id': 'X4.204.1'}
# cue {'type': 'speculation', 'ref': 'X4.204.1'}
# sentence {'id': 'S4.205'}
# sentence {'id': 'S4.206'}
# sentence {'id': 'S4.207'}
# sentence {'id': 'S4.208'}
# sentence {'id': 'S4.209'}
# xcope {'id': 'X4.209.1'}
# cue {'type': 'speculation', 'ref': 'X4.209.1'}
# sentence {'id': 'S4.210'}
# sentence {'id': 'S4.211'}
# sentence {'id': 'S4.212'}
# xcope {'id': 'X4.212.2'}
# cue {'type': 'speculation', 'ref': 'X4.212.2'}
# sentence {'id': 'S4.213'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S4.214'}
# xcope {'id': 'X4.214.2'}
# cue {'type': 'speculation', 'ref': 'X4.214.2'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.215'}
# sentence {'id': 'S4.216'}
# sentence {'id': 'S4.217'}
# sentence {'id': 'S4.218'}
# xcope {'id': 'X4.218.2'}
# cue {'type': 'speculation', 'ref': 'X4.218.2'}
# sentence {'id': 'S4.219'}
# sentence {}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S4.221'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.223'}
# xcope {'id': 'X4.223.1'}
# cue {'type': 'speculation', 'ref': 'X4.223.1'}
# sentence {'id': 'S4.224'}
# sentence {'id': 'S4.225'}
# sentence {'id': 'S4.226'}
# sentence {'id': 'S4.227'}
# sentence {'id': 'S4.228'}
# sentence {'id': 'S4.229'}
# sentence {'id': 'S4.230'}
# sentence {'id': 'S4.231'}
# sentence {'id': 'S4.232'}
# sentence {'id': 'S4.233'}
# xcope {'id': 'X4.233.1'}
# cue {'type': 'negation', 'ref': 'X4.233.1'}
# sentence {'id': 'S4.234'}
# sentence {'id': 'S4.235'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S4.236'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.237'}
# xcope {'id': 'X4.237.1'}
# cue {'type': 'negation', 'ref': 'X4.237.1'}
# sentence {'id': 'S4.238'}
# sentence {'id': 'S4.239'}
# sentence {'id': 'S4.240'}
# xcope {'id': 'X4.240.1'}
# cue {'type': 'speculation', 'ref': 'X4.240.1'}
# sentence {'id': 'S4.241'}
# sentence {'id': 'S4.242'}
# sentence {'id': 'S4.243'}
# xcope {'id': 'X4.243.1'}
# cue {'type': 'speculation', 'ref': 'X4.243.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S4.244'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S4.245'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.246'}
# sentence {'id': 'S4.247'}
# sentence {'id': 'S4.248'}
# sentence {'id': 'S4.249'}
# xcope {'id': 'X4.249.1'}
# cue {'type': 'speculation', 'ref': 'X4.249.1'}
# sentence {'id': 'S4.250'}
# sentence {'id': 'S4.251'}
# xcope {}
# cue {'type': 'speculation', 'ref': 'X4.251.1'}
# sentence {'id': 'S4.252'}
# xcope {}
# cue {'type': 'speculation', 'ref': 'X4.252.1'}
# sentence {'id': 'S4.253'}
# xcope {}
# cue {'type': 'negation', 'ref': 'X4.252.1'}
# sentence {'id': 'S4.254'}
# xcope {}
# cue {'type': 'speculation', 'ref': 'X4.254.1'}
# sentence {'id': 'S4.255'}
# sentence {'id': 'S4.256'}
# xcope {}
# cue {'type': 'speculation', 'ref': 'X4.254.1'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S4.257'}
# xcope {}
# cue {'type': 'negation', 'ref': 'X4.257.1'}
# xcope {}
# cue {'type': 'negation', 'ref': 'X4.257.2'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S4.258'}
# sentence {'id': 'S4.259'}
# sentence {'id': 'S4.260'}
# xcope {'id': 'X4.260.1'}
# cue {'type': 'speculation', 'ref': 'X4.260.1'}
# sentence {'id': 'S4.261'}
# sentence {'id': 'S4.262'}
# xcope {'id': 'X4.262.2'}
# cue {'type': 'speculation', 'ref': 'X4.262.2'}
# sentence {'id': 'S4.263'}
# DocumentsE {'type': 'biomedical articles'}
# DocID {'type': 'PMCID'}
# DocumentPart {'type': 'Title'}
# sentence {'id': 'S5.1'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S5.2'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S5.3'}
# sentence {'id': 'S5.4'}
# sentence {'id': 'S5.5'}
# xcope {'id': 'X5.5.1'}
# cue {'type': 'speculation', 'ref': 'X5.5.1'}
# sentence {'id': 'S5.6'}
# sentence {'id': 'S5.7'}
# xcope {'id': 'X5.7.1'}
# cue {'type': 'speculation', 'ref': 'X5.7.1'}
# sentence {'id': 'S5.8'}
# sentence {'id': 'S5.9'}
# sentence {'id': 'S5.10'}
# sentence {'id': 'S5.11'}
# xcope {'id': 'X5.11.2'}
# cue {'type': 'speculation', 'ref': 'X5.11.2'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S5.12'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S5.13'}
# xcope {'id': 'X5.11.2'}
# cue {'type': 'negation', 'ref': 'X5.11.2'}
# sentence {'id': 'S5.14'}
# sentence {'id': 'S5.15'}
# sentence {'id': 'S5.16'}
# sentence {'id': 'S5.17'}
# sentence {'id': 'S5.18'}
# sentence {'id': 'S5.19'}
# xcope {'id': 'X5.19.1'}
# cue {'type': 'speculation', 'ref': 'X5.19.1'}
# sentence {'id': 'S5.20'}
# sentence {'id': 'S5.21'}
# sentence {'id': 'S5.22'}
# xcope {'id': 'X5.22.2'}
# cue {'type': 'speculation', 'ref': 'X5.22.2'}
# sentence {'id': 'S5.23'}
# xcope {'id': 'X5.23.1'}
# cue {'type': 'speculation', 'ref': 'X5.23.1'}
# xcope {'id': 'X5.23.1'}
# cue {'type': 'speculation', 'ref': 'X5.23.1'}
# sentence {'id': 'S5.24'}
# xcope {'id': 'X5.24.1'}
# cue {'type': 'speculation', 'ref': 'X5.24.1'}
# sentence {'id': 'S5.25'}
# sentence {'id': 'S5.28'}
# xcope {'id': 'X5.28.1'}
# cue {'type': 'speculation', 'ref': 'X5.28.1'}
# sentence {'id': 'S5.29'}
# xcope {'id': 'X5.29.1'}
# cue {'type': 'speculation', 'ref': 'X5.29.1'}
# xcope {'id': 'X5.29.1'}
# cue {'type': 'speculation', 'ref': 'X5.29.1'}
# sentence {'id': 'S5.30'}
# xcope {'id': 'X5.30.1'}
# cue {'type': 'speculation', 'ref': 'X5.30.1'}
# xcope {'id': 'X5.28.1'}
# cue {'type': 'negation', 'ref': 'X5.28.1'}
# sentence {'id': 'S5.31'}
# sentence {'id': 'S5.32'}
# sentence {'id': 'S5.33'}
# sentence {'id': 'S5.34'}
# sentence {'id': 'S5.35'}
# sentence {'id': 'S5.36'}
# sentence {'id': 'S5.37'}
# sentence {'id': 'S5.38'}
# sentence {'id': 'S5.39'}
# sentence {'id': 'S5.41'}
# sentence {'id': 'S5.42'}
# xcope {'id': 'X5.42.1'}
# cue {'type': 'speculation', 'ref': 'X5.42.1'}
# sentence {'id': 'S5.43'}
# sentence {'id': 'S5.44'}
# sentence {'id': 'S5.45'}
# sentence {'id': 'S5.46'}
# sentence {'id': 'S5.47'}
# xcope {'id': 'X5.47.1'}
# cue {'type': 'speculation', 'ref': 'X5.47.1'}
# sentence {'id': 'S5.48'}
# sentence {'id': 'S5.50'}
# xcope {'id': 'X5.50.1'}
# cue {'type': 'speculation', 'ref': 'X5.50.1'}
# sentence {'id': 'S5.51'}
# xcope {'id': 'X5.51.1'}
# cue {'type': 'speculation', 'ref': 'X5.51.1'}
# sentence {'id': 'S5.52'}
# sentence {'id': 'S5.53'}
# xcope {'id': 'X5.53.1'}
# cue {'type': 'negation', 'ref': 'X5.53.1'}
# sentence {'id': 'S5.54'}
# xcope {'id': 'X5.53.1'}
# cue {'type': 'speculation', 'ref': 'X5.53.1'}
# DocumentPart {'type': 'SectionTitle'}
# sentence {'id': 'S5.55'}
# DocumentPart {'type': 'SubSectionTitle'}
# sentence {'id': 'S5.56'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S5.57'}
# sentence {'id': 'S5.58'}
# sentence {'id': 'S5.59'}
# sentence {'id': 'S5.60'}
# sentence {'id': 'S5.61'}
# xcope {'id': 'X5.61.1'}
# cue {'type': 'speculation', 'ref': 'X5.61.1'}
# sentence {'id': 'S5.62'}
# sentence {'id': 'S5.63'}
# sentence {'id': 'S5.64'}
# sentence {'id': 'S5.65'}
# xcope {'id': 'X5.65.1'}
# cue {'type': 'speculation', 'ref': 'X5.65.1'}
# sentence {'id': 'S5.66'}
# xcope {'id': 'X5.66.1'}
# cue {'type': 'negation', 'ref': 'X5.66.1'}
# sentence {'id': 'S5.67'}
# sentence {'id': 'S5.68'}
# sentence {'id': 'S5.69'}
# sentence {'id': 'S5.70'}
# sentence {'id': 'S5.71'}
# sentence {'id': 'S5.72'}
# xcope {'id': 'X5.72.1'}
# cue {'type': 'speculation', 'ref': 'X5.72.1'}
# sentence {'id': 'S5.74'}
# xcope {'id': 'X5.74.1'}
# cue {'type': 'speculation', 'ref': 'X5.74.1'}
# sentence {'id': 'S5.75'}
# sentence {'id': 'S5.76'}
# DocumentPart {'type': 'text'}
# sentence {'id': 'S5.77'}
# DocumentPart {'type': 'Text'}
# sentence {'id': 'S5.78'}
# sentence {'id': 'S5.79'}
# sentence {'id': 'S5.84'}
# xcope {'id': 'X5.84.1'}
# cue {'type': 'speculation', 'ref': 'X5.84.1'}
# sentence {'id': 'S5.86'}
# xcope {'id': 'X5.86.1'}
# cue {'type': 'negation', 'ref': 'X5.86.1'}
# sentence {'id': 'S5.87'}
# sentence {'id': 'S5.88'}
# sentence {'id': 'S5.89'}
# sentence {'id': 'S5.90'}
# sentence {'id': 'S5.94'}
# xcope {'id': 'X5.94.1'}
# cue {'type': 'negation', 'ref': 'X5.94.1'}
# sentence {'id': 'S5.95'}
# xcope {'id': 'X5.95.1'}
# ...
# البكتريا والظروف المزرعية الآخرى.
# تختلف مكونات الوسط أو البيئة التي تعيش فيها البكتريا في طبيعتها كأن
# تكون صلبة أو سائلة أو متجانسة أو غير متجانسة فضلاً عن إختلافها في تركيز ونوع المغذيات والأملاح مما
# ينعكس سلباً أو إيجاباً في نمو البكتريا وإنتاجها للمواد الأيضية
# فالوسط الذي يحتوي على مواد بروتينية عموماً
# يشجع نمو البكتريا لأنه يزودها بما تحتاجه من مغذيات لبناء خلاياها وغالباً ما تحتوي الأوساط الزرعية
# (المجهزة من قبل الشركات المختصة) مواد غنية بمحتواها من البروتينات والحوامض الأمينية مثل خلاصة
# والببتون وقد يضاف الدم لجعل الوسط إغنائياً Yeast extract وخلاصة الخميرة Meat extract اللحم
# .( وتحفيز البكتريا على إنتاج إنزيمات أو بروتينات معينة يشكل بعضها عوامل ضراوة مثل الهيمولايسن
# إن الهدف من هذه الدراسة هو التعرف على مدى صلاحية بعض المخلفات النباتية والحيوانية ذات الكلفة القليلة
# لنموالبكتريا وانتاج مواد أيضية معينة مثل حال الدم وامكانية استعمالها في تحضير أوساط بديلة عن الأوساط
# التجارية المكلفة لتنمية البكتريا لتوفير أوساط اقتصادية سهلة التحضير
# المواد وطرائق العمل
# None
# عزلة البكتريا
# عزلة البكتريا
# من قسم علوم الحياة – جامعة بغداد ، نميت البكتريا على وسط S. aureus تم الحصول على عزلة البكتريا
# للتأكد من نقاوتها وصفاتها.  Nutrient agar الاكار المغذي
# وحضنت بدرجة 37 م لمدة 18 ساعة واستعملت هذه المزرعة لتلقيح الأوساط المختلفة
# الأوساط الزرعية
# استعملت الأوساط الزرعية الآتية لتنمية البكتريا وإنتاج حال الدم بعد تعقيمها بدرجة 121 م لمدة 15 دقيقة.
# (Merk) حضر كما وصف من قبل الشركة المجهزة :( BHI ) 1 . وسط نقيع القلب والدماغ
# أوساط المخلفات النباتية والحيوانية: استعملت مخلفات نباتية جافة تضمنت نخالة الرز وكسبة زهرة الشمس
# وقشور البطاطا فضلاً عن مسحوق عظام الدجاج بأعتباره من المخلفات الحيوانية
# حضرت أوساط زرعية صلبة وسائلة من هذه المواد وذلك بأخذ أوزان معينة منها وإضافتها إلى محلول
# المحضر بتركيز 0.2 مولار ورقم هيدروجيني 7.2 للحصول على Phosphate buffer الفوسفات الداريء
# تركيزين( 5% و 10 % وزن : حجم) وسخنت لحد الغليان لمدة خمس دقائق، ثم رشحت من خلال قطعة قماش
# وأخذ الراشح.
# حضر الوسط الصلب بإضافة الأكار الى
# الراشح بنسبة 2 % وبعد تعقيمه أضيف الدم بنسبة 10 % وصب في أطباق بتري معقمة
# وحضر الوسط السائل
# من الراشح بدون أي إضافة في دوارق سعة 100 مليلتر بواقع 50 مليلتر من الوسط في كل دورق وعقم بجهاز
# التعقيم (الموصدة).
# تحضير عالق كريات الدم الحمر
# وضعت كميات معينة من دم الانسان في أنابيب تنبيذ ونبذت بسرعة 3000 دورة / دقيقة لمدة 10 دقائق ثم
# Phosphate فصلت كريات الدم الحمر المترسبة عن الرائق وغسلت عدة مرات بمحلول الفوسفات الملحي
# .(4) buffer saline PBS
# تنمية البكتريا على الأوساط الصلبة وملاحظة تحلل الدم
# زرعت الأوساط المزودة بالدم بجزء من عالق البكتريا ( 0.1 مليلتر) الذي نشر على سطح الوسط وحضنت
# الأطباق بدرجة 37 م لمدة 24 ساعة مع ملاحظة نمو ومناطق تحلل الدم حول المستعمرات
# تنمية البكتريا في الأوساط السائلة وقياس فعالية حال الدم
# لقحت الأوساط السائلة ب 0.5 مليلتر من مزرعة البكتريا المنشطة وحضنت بدرجة 37 م لمدة 24 ساعة،
# وتم
# للمزرعة بطول Optical Density متابعة النمو وإنتاج حال الدم أثناء هذه المدة وذلك بقياس الكثافة الضوئية
# موجي 550 نانوميتر بعد مدد زمنية معينة الذي يعد مقياساً للخلايا الموجودة في العالق
# وقدرت إنتاجية
# الهيمولايسين بتقدير فعاليته ( 5) وذلك بعدعمل نبذ للمزرعة بظروف مبردة بسرعة ( 5000 دورة/دقيقة) لمدة
# 30 دقيقة وفصل الرائق عن الراسب ورشح الرائق من خلال أغشية ترشيح قطر ثقوبها 0.22 مايكرون
# أضيف 5 مايكرولتر من الراشح إلى 1 مليلتر من عالق كريات الدم الحمر بتركيز 2 % وحضنت بدرجة 37 م
# لمدة 15 دقيقة ثم نبذ العالق بسرعة 3000 دورة / دقيقة لمدة 10 دقائق وفصل الرائق وتم قياس الكثافة
# النتائج والمناقشة
# وإنتاج حال الدم في الأوساط الصلبة S. aureus نمو
# نمت البكتريا بشكل جيد في جميع الأوساط المحضرة من المواد النباتية (نخالة الرز وكسبة زهرة الشمس وقشور
# الذي استعمل للمقارنة وظهر تحلل الدم (BHI) البطاطا وعظام الدجاج) فضلاً عن وسط أكار القلب والدماغ
# .( بشكل واضح في هذه الأوساط (جدول
# ولوحظ أن كثافة النمو في الأوساط المحضرة من نخالة الرز وعظام الدجاج كان أكثر من بقية الأوساط إذ كانت
# المستعمرات كثيفة في هذين الوسطين
# وقد يعود ذلك الى إحتوائهما على المواد المغذية التي تشجع نمو البكتريا
# كالبروتينات والحوامض الأمينية أكثر من غيرها
# غالبا
# تأكيد
# لا
# على الأغلب
# لا
# لم
# المتوقع
# لا
# عدم
# تحري
# اظهر
# ان نتأكد
# لم
# احجية
# لوحظ
# يبدي
# يسبب
# عدم
# ابدى
# ادى
# اشير
# اشير
# تتباين
# لوحظ
# لوحظ
# لا
# وجدت
# يمكن
# اظهرت
# ليس
# ليس
# لم
# لتأكيد
# يلاحظ
# يعتمد
# لاحظنا
# اشار
# لاحظناه
# نعتقد
# لا
# قد
# يشير
# لا
# تشير
# تعد
# لا
# لا
# تعد
# من...او
# غالبا
# لاسيما
# تعد
# يمكن
# تجريبيا
# لا
# عادة
# دون
# منعت
# لوحظ
# اظهرت
# لوحظ
# يعد
# يعد
# تعد
# دراسة
# يلاحظ
# لم
# لا
# لا
# لوحظ
# يعتقد
# لا
# التأكد
# لا
# بين
# عدم
# يمكن ان
# لا
# قديفسر
# قد
# عدم
# عدم
# قد يتسبب
# قد
# يمكن
# عدم
# قد
# تبين
# يعتقد
# يعد
# غالبا
# يبدو
# يفترض
# فقط
# لا
# لا
# يمكن
# او
# عدم
# يمكن
# عدم
# يمكن
# لا
# يؤدي
# قد يسبب
# لم
# لا
# لم
# نتيجة
# اظهرت
# يتوقع
# قد
# دون
# لوحظ
# يحمل احتمال
# تراوحت
# تفاوتت
# نلاحظ
# لوحظ
# اكتشف
# اكتشف
# لم
# نلاحظ
# نلاحظ
# قد
# يؤدي
# قد
# None
# عدم
# تشير
# قد
# لوحظ
# عدم
# يعد
# يمكن
# يراوح
# تظهر
# تبين
# يعزى
# اشار
# تبين
# يمكن
# يعزى
# لاحظ
# تفسر
# بينت
# يمكن
# غير
# لا
# تؤدي
# لم
# لا
# او
# يدل
# يدل
# روقبت
# لا
# لم
# لم
# لم
# لا
# يمكن
# لم
# يبدو
# لم
# يدل
# يدل
# غير
# لم
# لم
# يدل
# قد
# لم
# قد
# ما لم
# لا
# تعد
# لا
# اعتمادا
# نجد
# لا
# لا
# يدل
# فلم
# كانت
# يمكن
# اظهرت
# يشير
# لا
# بينت
# لا
# اظهرت
# تعد
# وجد
# يعد
# عدم
# استبعد
# راوحت
# راوحت
# تشير
# عدم
# يشير
# اشار
# لم
# ربما
# ليس
# ليس
# غير
# يؤدي
# من الممكن
# غير
# قد توجد
# من الممكن
# لم
# لا
# لا
# يمكن
# يسبب
# X4.59.3
# لا
# عدم
# حللت
# لا
# لا
# لا
# يشبه
# لا
# غير
# لا
# دون
# اشارت
# قد
# دون
# لم
# لم
# لا
# يمكن
# نستنتج
# يعد
# تراوح
# روقب
# اظهرت
# النتيجة
# يعد
# لم
# عدم
# تظهر
# روقبت
# يبين
# التاكد
# بملاحظة
# عدم
# تبين
# وجد
# دون
# لم
# خلصت
# يسمح
# نطرح
# مدى
# تبين
# لم
# تعد
# احصائيا
# اصبح
# يحتم
# تحدث
# او
# يمكن
# غالبا
# صار
# عدم
# يغلب
# كانت
# نجد
# نجد
# لم
# اشارت
# كانت
# يشير
# عدم
# يعكس
# قد
# تأكيد
# لم
# لم
# درءا
# اصبح
# دراسة
# كان
# لا
# اظهرت
# يبدو
# يمكن
# دون
# من الممكن
# يمكن
# غير
# غير
# لم
# قد يكون
# دون
# عدم
# قد
# عدم
# يمكن
# لا
# يمكننا
# تؤكد
# يؤدي
# يعد
# يعد
# يتوقع
# لا
# راوحت
# حسبت
# درست
# لا
# لا
# لم
# يبين
# لا
# يبين
# لا
# لا
# غير
# تملك
# لا
# غير
# خلاف
# نسبة
# معرفة
# كانت
# تظهر
# لكنه
# اذا ظهر
# لا
# ما
# يعد
# تعد
# لا
# امكن
# يعود
# أو
# استبعد
# غير
# يظهر
# راوحت
# كانت
# لوحظ
# يفسر
# تشيع الاصابه
# قد
# لوحظ
# يمكنها
# وجد
# ملاحظ
# غير
# لا
# تبيان
# وجد
# قد يدل ذلك على فائدة
# لكن مع
# توقع
# غير
# الاجدى
# غير
# ووجد
# ليس
# وجدت
# ليس
# لا
# نجد
# ملاحظ
# يبدو
# غير
# يبدو
# نلاحظ
# لوحظ
# لوحظ
# قد
# غير
# ظهرت
# غير
# مجهول
# لا
# لم
# لم
# على العكس
# بينت
# قد
# تقريبا
# عدم
# تدعى
# الشائع
# غياب
# تسبب
# احيانا
# لا
# قد
# عديمي
# المجهولة
# لا
# احتمالا
# عد
# مجهول
# مجهول
# مجهول
# عدم
# لا
# عدم
# لا
# عدت
# استثني
# عدم
# استبعدت
# لا
# لم
# فلم
# ليسا
# قد
# محتمل
# قد
# ليس
# ليس
# قد
# قد
# عدت
# لوحظ
# ليس
# المجهول
# اظهرت
# يقدر
# غير
# يبدو
# وجد
# لم
# ربما
# لم
# يمكن
# لم
# يفسر
# لم
# ارجحيه
# لوحظ
# لوحظ
# لا
# ليس
# لسن
# ليس
# قد رجحت
# عكس
# غير
# عادة
# لا
# عادة
# عكس
# عكس
# المعتاد
# عادة
# قد
# يؤيد ذلك
# يمكن
# قد يكون
# عادة
# قد يكون
# نقترح
# لا
# امكن
# اطهر
# تعد
# يعد
# يعد
# تعد
# تظهر
# قد مكنت
# لا
# اشار
# اشارت
# بينت
# يعزى
# اظهر
# يستطيع
# يعزى
# لوحظ
# يعزى سبب
# بالامكان
# اوضحت
# لم
# يمكن
# غير
# غير
# قد تكون
# يمكن
# قد تكون
# يمكن
# يمكن
# لم
# بدون
# يمكن
# غير
# غير
# لا
# لا
# اشارت
# يشير
# لا
# يمكن
# عادة
# لا
# غير
# عادة
# يمكن
# يمكن
# لا
# غياب
# عدم
# قد
# يمكن
# يشير
# عدم
# يمكن
# قد
# يمكن
# بدون
# توضيح
# تعد
# استثناء
# بدون
# تمكنا
# تمكن
# اشار
# غير
# لا
# لم
# ليست
# غير
# لم
# بينت
# عادة
# لا
# بدون
# ليس
# بدون
# لم
# اظهرت
# فقط
# ربما
# might
# غالبا
# يبدو
# وجد
# الاغلبيه
# من المحتمل
# عدم
# فقط
# لم
# لم
# اكدت
# غير
# غالبا
# يمكن
# يؤدي
# غير
# غير
# تمكن
# لا
# غير
# بدون
# لا
# عدم
# عادة
# يعد
# الشائعة
# يؤدي
# بدلا
# اشارت
# غياب
# اوضحت
# لم
# غير
# فقط
# بينت
# بينت
# اوضحت
# لم
# يمكن
# عادة
# يؤدي
# يسبب
# يؤدي
# تباينت
# لم
# يفترض
# لم
# تهديم
# يفترض
# تحليله
# اشارت
# اشارت
# اظهرت
# تعتبر
# تعتبر الدراسة التحولات
# اوضحت
# ليس
# لا
# يشير
# يشير
# سماته
# اعتبرها
# يختلف
# لا
# لا
# يشبه
# شيوعا
# لا
# لا
# على العكس
# لا
# يمكن
# لا
# اشار
# لا
# دون
# اشار
# اشار
# تتناقض
# اعتبرت
# نسبيا
# شملت
# شيوعا
# فقدان
# اظهرت
# غياب
# اقترح
# عشوائية
# التحري
# لم
# اظهرت
# لم
# تعتبر
# تعتبر
# تعذرذلك
# معكوس
# شخصت
# فسرت
# غالبا
# تأكيد
# لا
# على الأغلب
# لا
# لم
# المتوقعتحسن الاعراض
# لا
# عدم
# غالبا
# تأكيد
# لا
# على الأغلب
# لا
# لم
# المتوقعتحسن الاعراض
# لا
# اظهرت
# مقارنتها
# تغاير
# يعود
# عدم
# يدل
# عدم
# عدم
# سالبه
# اضداد
# لذلك
# بينت
# متعاكس
# اهمل
# قدرت
# غير
# غير
# لا
# غياب
# يدل
# تقدير
# قدر
# اما
# قد
# يبدو
# تثبيط
# درس
# تثبيط
# اقتصر
# تثبيط
# لوحظ
# قد
# غالبا
# ما
# يتراوح
# يمكن
# يمكن
# تشخيص
# تشخيص
# تقدير
# دراسة
# قيد
# عدم
# عدم
# دراسة
# None
# المائي
# قورنت
# دراسة
# عدت
# عدم
# None
# وجد
# يثبط
# يعزى
# بينت
# لم
# لا
# لم
# دراسة
# قيد
# وجد
# قيد
# None
# قد تعزى
# حد ممكن
# قد سجلت
# بينما
# يبين
# None
# None
# بينما
# لم
# ظهر
# بينما
# لوحظ
# بدون
# اشار
# يمكن
# ربما
# قد
# لم
# لم
# غير
# لوحظ
# اظهر
# اظهرت
# ضد
# تعد
# بينت
# اظهر
# لم
# امكن
# تقدير
# بينت
# تعد
# للتحري
# اظهر
# لم
# لم
# مضاد
# قد يكون
# اشار
# اقتصر
# تثبيط
# لوحظ
# تغايرت
# دراسة
# لا
# اعتمادا
# حيث
# يمكن
# التشخيص
# التحري
# التجارب
# قيد
# تجارب
# اظهرت
# التحري
# يلاحظ
# تشير
# قد يعزى
# امكانية
# لوحظ
# يلاحظ
# يعزى
# غالبا ما
# يلاحظ
# لا
# عدم
# None
# المائي
# غير
# قد تكون
# قيد
# عدم
# اظهرت
# لم
# قد يشير
# لوحظ
# قيد
# لم
# غير
# لا
# دراسة
# دراسة
# بينت
# ضمان
# تشخيص
# تشخيص
# درست
# لوحظ
# اظهر
# اظهرت
# لم
# لوحظ
# لوحظ
# يلاحظ
# عدم
# يمكن
# غير
# عدم
# قدرت
# يعد
# وجد
# غالبا
# ووجدت
# اشارت
# من الممكن
# لا
# قد يعود
# التحري
# اظهرت
# دراسة
# اظهرت
# عدم
# دون
# غير
# يلاحظ
# يؤدي
# عزل
# عدم
# حيز
# استثناء
# التحري
# تشخيص
# اختبار
# اختبار
# التحري
# دراسة
# لا
# قيد
# عدم
# اظهرت
# لوحظ
# يدل
# يدل
# غير
# لم
# لم
# يدل
# قد
# لم
# قد
# ما لم
# لا
# قاعدة البيانات البشرية ومعرفة نسبة انتماء نمط الdna
# مهمة
# لا
# اعتمادا
# نجد
# لا
# لا
# يدل
# فلم
# may
# كانت
# يمكن
# اظهرت
# يشير
# لا
# بينت
# دون
# تعد
# لا
# اظهرت
# تعد
# وجد
# يعد
# قد
# قد
# الغالبية
# عادة
# اشار
# لا
# لا
# دون
# غير
# مختلفة
# دون
# عدم
# دون
# يعتقد
# توضيح
# غير
# فقدان
# ليس
# ليس
# لا
# لا
# لا
# غير
# يمكن
# لوحظ
# لوحظت
# يبدو
# احد
# يمكن
# غيرها
# غير
# غالبا
# امكانية
# عزل
# بدون
# قدرت
# لوحظ
# قد
# غالبا
# تأكيد
# لا
# على الأغلب
# لا
# لم
# المتوقع
# لا
# عدم
# تحري
# اظهر
# ان نتأكد
# لم
# احجية
# لوحظ
# يبدي
# يسبب
# عدم
# ابدى
# ادى
# اشير
# اشير
# تتباين
# لوحظ
# لوحظ
# لا
# وجدت
# يمكن
# اظهرت
# ليس
# ليس
# لم
# لتأكيد
# يلاحظ
# يعتمد
# لاحظنا
# اشار
# لاحظناه
# نعتقد
# لا
# قد
# يشير
# لا
# تشير
# تعد
# لا
# لا
# تعد
# من...او
# غالبا
# لاسيما
# تعد
# يمكن
# تجريبيا
# لا
# عادة
# دون
# منعت
# لوحظ
# اظهرت
# لوحظ
# يعد
# يعد
# تعد
# دراسة
# يلاحظ
# لم
# لا
# لا
# لوحظ
# يعتقد
# لا
# التأكد
# لا
# بين
# عدم
# يمكن ان
# لا
# قديفسر
# قد
# عدم
# عدم
# قد يتسبب
# قد
# يمكن
# عدم
# قد
# تبين
# يعتقد
# يعد
# غالبا
# يبدو
# يفترض
# فقط
# لا
# لا
# يمكن
# او
# عدم
# يمكن
# عدم
# يمكن
# لا
# يؤدي
# قد يسبب
# لم
# لا
# لم
# نتيجة
# اظهرت
# يتوقع
# قد
# دون
# لوحظ
# يحمل احتمال
# تراوحت
# تفاوتت
# نلاحظ
# لوحظ
# اكتشف
# اكتشف
# لم
# نلاحظ
# نلاحظ
# قد
# يؤدي
# قد
# عدم
# تشير
# قد
# لوحظ
# عدم
# يعد
# يمكن
# يراوح
# تظهر
# تبين
# يعزى
# اشار
# تبين
# يمكن
# يعزى
# لاحظ
# تفسر
# بينت
# يمكن
# غير
# لا
# تؤدي
# لم
# لا
# او
# يدل
# يدل
# روقبت
# لا
# لم
# لم
# لم
# لا
# يمكن
# لم
# يبدو
# لم
# يدل
# يدل
# غير
# لم
# لم
# يدل
# قد
# لم
# قد
# ما لم
# لا
# تعد
# لا
# اعتمادا
# نجد
# لا
# لا
# يدل
# فلم
# كانت
# يمكن
# اظهرت
# يشير
# لا
# بينت
# لا
# اظهرت
# تعد
# وجد
# يعد
# عدم
# استبعد
# راوحت
# راوحت
# تشير
# عدم
# يشير
# اشار
# لم
# ربما
# ليس
# ليس
# غير
# يؤدي
# من الممكن
# غير
# قد توجد
# من الممكن
# لم
# لا
# لا
# يمكن
# يسبب
# X4.59.3
# لا
# عدم
# حللت
# لا
# لا
# لا
# يشبه
# لا
# غير
# لا
# دون
# اشارت
# قد
# دون
# لم
# لم
# لا
# يمكن
# نستنتج
# يعد
# تراوح
# روقب
# اظهرت
# النتيجة
# يعد
# لم
# عدم
# تظهر
# روقبت
# يبين
# التاكد
# بملاحظة
# عدم
# تبين
# وجد
# دون
# لم
# خلصت
# يسمح
# نطرح
# مدى
# تبين
# لم
# تعد
# احصائيا
# اصبح
# يحتم
# تحدث
# او
# يمكن
# غالبا
# صار
# عدم
# يغلب
# كانت
# نجد
# نجد
# لم
# اشارت
# كانت
# يشير
# عدم
# يعكس
# قد
# تأكيد
# لم
# لم
# درءا
# اصبح
# دراسة
# كان
# لا
# اظهرت
# يبدو
# يمكن
# دون
# من الممكن
# يمكن
# غير
# غير
# لم
# قد يكون
# دون
# عدم
# قد
# عدم
# يمكن
# لا
# يمكننا
# تؤكد
# يؤدي
# يعد
# يعد
# يتوقع
# لا
# راوحت
# حسبت
# درست
# لا
# لا
# لم
# يبين
# لا
# يبين
# لا
# لا
# غير
# تملك
# لا
# غير
# خلاف
# نسبة
# معرفة
# كانت
# تظهر
# لكنه
# اذا ظهر
# لا
# ما
# يعد
# تعد
# لا
# امكن
# يعود
# أو
# استبعد
# غير
# يظهر
# راوحت
# كانت
# لوحظ
# يفسر
# تشيع الاصابه
# قد
# لوحظ
# يمكنها
# وجد
# ملاحظ
# غير
# لا
# تبيان
# وجد
# قد يدل ذلك على فائدة
# لكن مع
# توقع
# غير
# الاجدى
# غير
# ووجد
# ليس
# وجدت
# ليس
# لا
# نجد
# ملاحظ
# يبدو
# غير
# يبدو
# نلاحظ
# لوحظ
# لوحظ
# قد
# غير
# ظهرت
# غير
# مجهول
# لا
# لم
# لم
# على العكس
# بينت
# قد
# تقريبا
# عدم
# تدعى
# الشائع
# غياب
# تسبب
# احيانا
# لا
# قد
# عديمي
# المجهولة
# لا
# احتمالا
# عد
# مجهول
# مجهول
# مجهول
# عدم
# لا
# عدم
# لا
# عدت
# استثني
# عدم
# استبعدت
# لا
# لم
# فلم
# ليسا
# قد
# محتمل
# قد
# ليس
# ليس
# قد
# قد
# عدت
# لوحظ
# ليس
# المجهول
# اظهرت
# يقدر
# غير
# يبدو
# وجد
# لم
# ربما
# لم
# يمكن
# لم
# يفسر
# لم
# ارجحيه
# لوحظ
# لوحظ
# لا
# ليس
# لسن
# ليس
# قد رجحت
# عكس
# غير
# عادة
# لا
# عادة
# عكس
# عكس
# المعتاد
# عادة
# قد
# يؤيد ذلك
# يمكن
# قد يكون
# عادة
# قد يكون
# نقترح
# لا
# امكن
# اطهر
# تعد
# يعد
# يعد
# تعد
# تظهر
# قد مكنت
# لا
# اشار
# اشارت
# بينت
# يعزى
# اظهر
# يستطيع
# يعزى
# لوحظ
# يعزى سبب
# بالامكان
# اوضحت
# لم
# يمكن
# غير
# غير
# قد تكون
# يمكن
# قد تكون
# يمكن
# يمكن
# لم
# بدون
# يمكن
# غير
# غير
# لا
# لا
# اشارت
# يشير
# لا
# يمكن
# عادة
# لا
# غير
# عادة
# يمكن
# يمكن
# لا
# غياب
# عدم
# قد
# يمكن
# يشير
# عدم
# يمكن
# قد
# يمكن
# بدون
# توضيح
# تعد
# استثناء
# بدون
# تمكنا
# تمكن
# اشار
# غير
# لا
# لم
# ليست
# غير
# لم
# بينت
# عادة
# لا
# بدون
# ليس
# بدون
# لم
# اظهرت
# فقط
# ربما
# might
# غالبا
# يبدو
# وجد
# الاغلبيه
# من المحتمل
# عدم
# فقط
# لم
# لم
# اكدت
# غير
# غالبا
# يمكن
# يؤدي
# غير
# غير
# تمكن
# لا
# غير
# بدون
# لا
# عدم
# عادة
# يعد
# الشائعة
# يؤدي
# بدلا
# اشارت
# غياب
# اوضحت
# لم
# غير
# فقط
# بينت
# بينت
# اوضحت
# لم
# يمكن
# عادة
# يؤدي
# يسبب
# يؤدي
# تباينت
# لم
# يفترض
# لم
# تهديم
# يفترض
# تحليله
# اشارت
# اشارت
# اظهرت
# تعتبر
# تعتبر الدراسة التحولات
# اوضحت
# ليس
# لا
# يشير
# يشير
# سماته
# اعتبرها
# يختلف
# لا
# لا
# يشبه
# شيوعا
# لا
# لا
# على العكس
# لا
# يمكن
# لا
# اشار
# لا
# دون
# اشار
# اشار
# تتناقض
# اعتبرت
# نسبيا
# شملت
# شيوعا
# فقدان
# اظهرت
# غياب
# اقترح
# عشوائية
# التحري
# لم
# اظهرت
# لم
# تعتبر
# تعتبر
# تعذرذلك
# معكوس
# شخصت
# فسرت
# غالبا
# تأكيد
# لا
# على الأغلب
# لا
# لم
# المتوقعتحسن الاعراض
# لا
# عدم
# غالبا
# تأكيد
# لا
# على الأغلب
# لا
# لم
# المتوقعتحسن الاعراض
# لا
# اظهرت
# مقارنتها
# تغاير
# يعود
# عدم
# يدل
# عدم
# عدم
# سالبه
# اضداد
# لذلك
# بينت
# متعاكس
# اهمل
# قدرت
# غير
# غير
# لا
# غياب
# يدل
# تقدير
# قدر
# اما
# قد
# يبدو
# تثبيط
# درس
# تثبيط
# اقتصر
# تثبيط
# لوحظ
# قد
# غالبا
# ما
# يتراوح
# يمكن
# يمكن
# تشخيص
# تشخيص
# تقدير
# دراسة
# قيد
# عدم
# عدم
# دراسة
# المائي
# قورنت
# دراسة
# عدت
# عدم
# وجد
# يثبط
# يعزى
# بينت
# لم
# لا
# لم
# دراسة
# قيد
# وجد
# قيد
# قد تعزى
# حد ممكن
# قد سجلت
# بينما
# يبين
# بينما
# لم
# ظهر
# بينما
# لوحظ
# بدون
# اشار
# يمكن
# ربما
# قد
# لم
# لم
# غير
# لوحظ
# اظهر
# اظهرت
# ضد
# تعد
# بينت
# اظهر
# لم
# امكن
# تقدير
# بينت
# تعد
# للتحري
# اظهر
# لم
# لم
# مضاد
# قد يكون
# اشار
# اقتصر
# تثبيط
# لوحظ
# تغايرت
# دراسة
# لا
# اعتمادا
# حيث
# يمكن
# التشخيص
# التحري
# التجارب
# قيد
# تجارب
# اظهرت
# التحري
# يلاحظ
# تشير
# قد يعزى
# امكانية
# لوحظ
# يلاحظ
# يعزى
# غالبا ما
# يلاحظ
# لا
# عدم
# المائي
# غير
# قد تكون
# قيد
# عدم
# اظهرت
# لم
# قد يشير
# لوحظ
# قيد
# لم
# غير
# لا
# دراسة
# دراسة
# بينت
# ضمان
# تشخيص
# تشخيص
# درست
# لوحظ
# اظهر
# اظهرت
# لم
# لوحظ
# لوحظ
# يلاحظ
# عدم
# يمكن
# غير
# عدم
# قدرت
# يعد
# وجد
# غالبا
# ووجدت
# اشارت
# من الممكن
# لا
# قد يعود
# التحري
# اظهرت
# دراسة
# اظهرت
# عدم
# دون
# غير
# يلاحظ
# يؤدي
# عزل
# عدم
# حيز
# استثناء
# التحري
# تشخيص
# اختبار
# اختبار
# التحري
# دراسة
# لا
# قيد
# عدم
# اظهرت
# لوحظ
# يدل
# يدل
# غير
# لم
# لم
# يدل
# قد
# لم
# قد
# ما لم
# لا
# قاعدة البيانات البشرية ومعرفة نسبة انتماء نمط الdna
# مهمة
# لا
# اعتمادا
# نجد
# لا
# لا
# يدل
# فلم
# may
# كانت
# يمكن
# اظهرت
# يشير
# لا
# بينت
# دون
# تعد
# لا
# اظهرت
# تعد
# وجد
# يعد
# قد
# قد
# الغالبية
# عادة
# اشار
# لا
# لا
# دون
# غير
# مختلفة
# دون
# عدم
# دون
# يعتقد
# توضيح
# غير
# فقدان
# ليس
# ليس
# لا
# لا
# لا
# غير
# يمكن
# لوحظ
# لوحظت
# يبدو
# احد
# يمكن
# غيرها
# غير
# غالبا
# امكانية
# عزل
# بدون
# قدرت
# لوحظ
# قد
# وتعد منطقة الشرق
# الأوسط من أغنى مناطق العالم بالثروة العشبية إذ تتوافر
# نحو 3600 عشبة في سورية وحدها.
#
#
#
#
#
#
#
#
#
#
# وهذا يعكس أهمية الوقاية من
# حدوث التهاب السحايا لتقليل مدة المكوث بالمشفى، ومن
# ثَم تخفيض العبء الاقتصادي عن الدولة والمجتمع
# ectopic sensory organ precursor cells
#
#
# وهذا ما هو ملاحظ في الجدول ( 3) أي
# إ  ن هناك نسبة كبيرة لوجود نقائل خفية للعقد اللمفاوية في
# العنق في المراحل المتقدمة من سرطان الحنجرة رغم
# الفحص السريري السلبي للعنق
# وبالاطلاع على الجدول ( 5) إِ ْ ذ أجري التصوير الطبقي
# 16T3-T المحوري ل 23 مريض سرطان حنجرة 4
# مريضاً غير معالجين شعاعياً و 7 مرضى معالجين
# شعاعياً، وقد وجدت ضخامة عقد لمفاوية في العنق على
# الطبقي المحوري لدى 6 مرضى من أصل 16 مريضاً
# غير معالجين شعاعياً،
#
#
#
#
# أ  ما خلال الثمانينيات فقد ضعف الحماس
# نظراً إلى بروز صورة جديدة في دراسات التوائم التي
# أظهرت نسبة تطابق قليلة بين التوائم وحيدي الزيجوت
# مما قلل من أهمية الدور الوراثي
# ويجب أن لا ننسى أن الأمراض التي تورث
# وراثة صبغية جسدية متنحية عادة ما تبدأ في سن باكر
#
#
# اظهرتالخلايا
# وتعتمد العدید من البرامج لحدس المستضدیة والحساسیة وتحدید الحوائم الخاصة بهذه الصفات ولكن نسبة كبیرة
# من هذه البرامج لا تعطي نتائج مضبوطة ( 3) في حین تربط برامج أخرى نسب محبة الماء/كراهیة الماء لامتداد
# محدد في حدس المستضدیة، وبرامج أخرى تأخذ بنظر الاعتبار الت ا ركیب الثانویة للبروتینات مثل الحلزونات
# وحركة قطع البروتین في الحسبان، وهناك برامج أخرى تستعمل الصفات المذكورة آنفاً Turns والصفائح واللفات
# .( بشكل مجتمع ( 27 ). ویستعمل البعض النسب هذه في توصیف بعض المحسسات
# إذ یتم تقیید البیوض بإستعمال مثبطات التیوبیولین كالنوكادوزول
# ویستعمل جهاز المطواع المجهري لإزالة وإستئصال الجسم (CytochalasineB) الشائعة كالسایتوكالاسین–ب
# القطبي الأول ومنطقة من السایتوبلازم الواقعة تحته ویتم بعدها تأكید عملیة الفصع وا إ زلة النواة بإستعمال صبغة
# .( لوسم دنا البویضة بنجاح والذي تمت الإشارة إلیه من قبل عدد كبیر من الباحثین ( 19 Hoechst33342
# Wolf etal. ( و ( 23 Campbell etal. (22)Smith( 20 ) والباحث ( 21 ) First و Crister وDominko etal
# . Artz etal. ( و( 26 Reggio etal.( و( 25 Dinnyes etal. ( و
# قد ت ا زمن وتطابق مع موقع كروموسومات الطور الاستوائي في كافة البیوض المعاملة ( Projection
# بالسكروز وبنسبة 100 %، في حین ان 31 % فقط من البیوض أظهرت إرتباطاً بین موقع الجسم القطبي الأول
# وبین مادتها الوراثیة فضلاً عن إن 95 % من البیوض التي تم معاملتها ب 0.3 مولاري مصل البقر الجنیني تم
# فصعها وا إ زلة نواتها بنجاح بإزالة جزء صغیر من السایتوبلازم الملاصق والقریب من البروز أو النتوء
# السایتوبلازمي
# ارتبط مفهوم النمط الجيني بعالم اللغة (جومسكي) ، الذي ميز بين مستويين للبنية ، هما البنية السطحية
# وقد ربط مفهوم البنية العميقة بعملية التوليد اللغوي من خلال اعطائها صيغا رياضية ،(Genotype ) والبنية العميقة
# .( منطقية ، واعتبرها مميزة للنوع ،وكدور الجينات في الكائنات الحية (جومسكي، 1985 ، ص 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the latter

# %%
from __future__ import print_function
def dbdepc(depen):
    li=[]
    import os
    import sys
    par=r'C:\Users\Fatima\Desktop\UNcertainity-arabic\parsed.txt'
    depen=r'C:\Users\Fatima\Desktop\UNcertainity-arabic\dep.txt'
    def my_datablock_iter(file):
        

        for line in file:
        # find ID
            if "root" in line:
            # build a list of lines until FIN is seen
                wanted = [line.strip()]
                for line in file:
                    line = line.strip()
                    if line == " ":
                        break
                    wanted.append(line)
            # hand block back to user
                yield wanted

    with open(depen,'r', encoding='utf-8') as fp:
        for datablock in  my_datablock_iter(fp):
            li.append(datablock)
    li=str(li).replace('[','').replace('"','')
    li= str(li).replace(']','').replace('"','')
    return li

# %%
from __future__ import print_function
def dbdepc1(par):
    li=[]
    import os
    import sys
    par=r'C:\Users\Fatima\Desktop\UNcertainity-arabic\parsed.txt'
    depen=r'C:\Users\Fatima\Desktop\UNcertainity-arabic\dep.txt'
    def my_datablock_iter(file):
        

        for line in file:
        # find ID
            if "(ROOT" in line:
            # build a list of lines until FIN is seen
                wanted = [line.strip()]
                for line in file:
                    line = line.strip()
                    if line == " ":
                        break
                    wanted.append(line)
            # hand block back to user
                yield wanted

    with open(par,'r', encoding='utf-8') as fp:
        for datablock in  my_datablock_iter(fp):
            li.append(datablock)
    li=str(li).replace('[','').replace('"','')
    li= str(li).replace(']','').replace('"','')
    li=str(li).replace("'", "")
    li=str(li).replace(", , , ", "")
    return li

# %%
from nltk.tree import Tree
from nltk.tree import ParentedTree


def get_lca_length(location1, location2):
    i = 0
    while i < len(location1) and i < len(location2) and location1[i] == location2[i]:
        i+=1
    return i

def get_labels_from_lca(ptree, lca_len, location):
    labels = []
    for i in range(lca_len, len(location)):
        labels.append(ptree[location[:i]].label())
    return labels

def findPath(ptree, text1, text2):
    leaf_values = ptree.leaves()
    leaf_index1 = leaf_values.index(text1)
    leaf_index2 = leaf_values.index(text2)

    location1 = ptree.leaf_treeposition(leaf_index1)
    location2 = ptree.leaf_treeposition(leaf_index2)

    #find length of least common ancestor (lca)
    lca_len = get_lca_length(location1, location2)

    #find path from the node1 to lca

    labels1 = get_labels_from_lca(ptree, lca_len, location1)
    #ignore the first element, because it will be counted in the second part of the path
    result = labels1[1:]
    #inverse, because we want to go from the node to least common ancestor
    result = result[::-1]

    #add path from lca to node2
    result = result + get_labels_from_lca(ptree, lca_len, location2)
    return result

# ptree = ParentedTree.fromstring(' (ROOT(S(NP (DT The) (NNS doctors)) \
#         (VP (VBP warn)(SBAR (IN that)(S(NP (NN smoking))(VP (MD may)(VP (VB harm)(NP (PRP$ our) (NNS lungs)))))))(. .)))')
# # print(ptree.pprint())

list1=[]



for neighbor in root.iter('cue'):
    list1.append(neighbor.text)
def listToStringWithoutBrackets(list1):
    return str(list1).replace('[','').replace(']','')
liss=listToStringWithoutBrackets(list1)

# %%
relations=['acl','advcl','advmod','amod','appos','aux','case','cc','ccomp','clf','compound','conj','cop','csubj','dep','det','discourse','dislocated','expl',
'fixed','flat','goeswith','iobj','list','mark','nmod','nsubj','nummod','obj','obl','orphan','parataxis','punct','reparandum','root','vocative','xcomp']

# %%
def isWordIn(word, string):
    return not(string.find(word) == -1)

# %%
# Simple usage

import os
import random
from multiprocessing import Process
from stanfordcorenlp import StanfordCoreNLP
nlp = StanfordCoreNLP(r'C:\Users\Fatima\Desktop\UNcertainity-arabic\stanford-corenlp-full-2018-10-05\stanford-corenlp-full-2018-10-05')
propst={'annotators': 'tokenize,pos,parse,depparse','pipelineLanguage':'ar','outputFormat':'text'}
propsp={'annotators': 'pos','pipelineLanguage':'ar','outputFormat':'text'}
propsconst={'annotators': 'parse','pipelineLanguage':'ar','outputFormat':'text'}
propsdep={'annotators': 'depparse','pipelineLanguage':'ar','outputFormat':'text'}


import csv
names_file = open('Arabic2019.csv', 'w+',encoding="utf-8")
writer = csv.writer(names_file)
writer.writerow(['cue','word','fp','d','scope','label'])
# for n in df['sentence/0/__text']:
parsed=nlp.annotate(sentence, properties=propsconst)
dep=nlp.annotate(sentence, properties=propsdep)
par=r'C:\Users\Fatima\Desktop\UNcertainity-arabic\parsed.txt'
depen=r'C:\Users\Fatima\Desktop\UNcertainity-arabic\dep.txt'

with open(depen, encoding='utf-8', mode='w') as file1:
    file1.truncate(0)
    file1.write(dep)
#     print(dep)
    
the_datablock=dbdepc(depen)
# print(the_datablock)
ww=the_datablock.split("', '")
# for rr in ww:
#     print(rr)

writer.writerow(ww)
  
with open(par, encoding='utf-8', mode='w') as file1:
    file1.truncate(0)
    file1.write(parsed)
#     print(dep)

www=dbdepc1(par)
# for rr in ww:
#     print(rr)
# writer.writerow(www)
# ptree = ParentedTree.fromstring(www)
ptree = ParentedTree.fromstring(www)
cue=''
d=''
id_s=0
scope=[]
label =False
for word in nlp.word_tokenize(sentence):
    if word in list1:
        cue=word
        for word in nlp.word_tokenize(sentence):
            fp=findPath(ptree,cue,word)
            for rr in ww:
                for dd in relations:
                    if isWordIn(d,rr):
                        d=dd
        for p in root.iter():
            if p is not None:
                pa =  p.find('sentence')
                if pa is not None:
                    for v in pa.find('xcope'):
                        if v is not None:
                            vi = v.find('xcope')
                            if word in vi:
                                scope.append(word)
                                label=True
                                
                        
            writer.writerow([cue,word,fp,d,scope,label])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-60ba0f6527cb> in <module>()
#      64                 pa =  p.find('sentence')
#      65                 if pa is not None:
# ---> 66                     for v in pa.find('xcope'):
#      67                         if v is not None:
#      68                             vi = v.find('xcope')
#
# TypeError: 'NoneType' object is not iterable

# %%
import os
import random
import csv
from multiprocessing import Process
from stanfordcorenlp import StanfordCoreNLP
nlp = StanfordCoreNLP(r'C:\Users\Fatima\Desktop\UNcertainity-arabic\stanford-corenlp-full-2018-10-05\stanford-corenlp-full-2018-10-05')
propst={'annotators': 'tokenize,pos,parse,depparse','pipelineLanguage':'ar','outputFormat':'text'}
propsp={'annotators': 'pos','pipelineLanguage':'ar','outputFormat':'text'}
propsconst={'annotators': 'parse','pipelineLanguage':'ar','outputFormat':'text'}
propsdep={'annotators': 'depparse','pipelineLanguage':'ar','outputFormat':'text'}

for group in root.iter('sentence'):
    import csv
    names_file = open('Arabic2019.csv', 'w+',encoding="utf-8")
    writer = csv.writer(names_file)
    writer.writerow(['cue','word','fp','d','scope','label'])
# for n in df['sentence/0/__text']:
    parsed=nlp.annotate(sentence, properties=propsconst)
    dep=nlp.annotate(sentence, properties=propsdep)
    par=r'C:\Users\Fatima\Desktop\UNcertainity-arabic\parsed.txt'
    depen=r'C:\Users\Fatima\Desktop\UNcertainity-arabic\dep.txt'

    with open(depen, encoding='utf-8', mode='w') as file1:
        file1.truncate(0)
        file1.write(dep)
#     print(dep)
    
    the_datablock=dbdepc(depen)
# print(the_datablock)
   ww=the_datablock.split("', '")
# for rr in ww:
#     print(rr)

    writer.writerow(ww)
  
    with open(par, encoding='utf-8', mode='w') as file1:
        file1.truncate(0)
        file1.write(parsed)
#     print(dep)

    www=dbdepc1(par)
# for rr in ww:
#     print(rr)
# writer.writerow(www)
# ptree = ParentedTree.fromstring(www)
    ptree = ParentedTree.fromstring(www)
    cue=''
    d=''
    id_s=0
    scope=[]
    label =False
    for word in nlp.word_tokenize(sentence):
        id_s+=1
        if word in list1:
            cue=word
            for word in nlp.word_tokenize(sentence):
                fp=findPath(ptree,cue,word)
                for rr in ww:
                    for dd in relations:
                        if isWordIn(d,rr):
                            d=dd
            for p in root.iter():
                if p is not None:
                    pa =  p.find('sentence')
                    if pa is not None:
                        for v in pa.find('xcope'):
                            if v is not None:
                                vi = v.find('xcope')
                                if word in vi:
                                    scope.append(word)
                                    label=True
                                
                        
            writer.writerow([id_s,cue,word,fp,d,scope,label])

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r'C:\Users\Fatima\Arabic2019.csv')

# %%
# import csv
# datanew = []
# rownum=0
# with open(r'C:\Users\Fatima\Arabic2019.csv',encoding="utf8") as csvfile:
#     reader = csv.DictReader(csvfile)
#     for row in reader:
#         rownum +=1
#         datanew.append(row)
# #     print ('row',datanew)
#     print(rownum)

# %%
from keras import preprocessing
import keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

vocabulary_size = 10000
tokenizer = Tokenizer(num_words= vocabulary_size)
tokenizer.fit_on_texts(df['id_s'])
sequences = tokenizer.texts_to_sequences(df['id_s'])
data = pad_sequences(sequences, maxlen=30)

data

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Activation
from keras.layers.embeddings import Embedding

model_lstm = Sequential()
model_lstm.add(Embedding(200, 100, input_length=30))
model_lstm.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model_lstm.add(Dense(1, activation='sigmoid'))
model_lstm.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# from sklearn.preprocessing import LabelBinarizer
# encoder = LabelBinarizer()
# transfomed_label = encoder.fit_transform(["ccue"])
# print(transfomed_label)
model_lstm.fit(data, df['label'],validation_split=0.4, epochs=1)

# %%
def create_conv_model():
    vocabulary_size=30
    model_conv = Sequential()
    model_conv.add(Embedding(vocabulary_size, 100, input_length=30))
    model_conv.add(Dropout(0.2))
    model_conv.add(Conv1D(64, 5, activation='relu'))
    model_conv.add(MaxPooling1D(pool_size=4))
    model_conv.add(LSTM(100))
    model_conv.add(Dense(1, activation='sigmoid'))
    model_conv.compile(loss='binary_crossentropy', optimizer='adam',    metrics=['accuracy'])
    return model_conv
model_conv = create_conv_model()
model_conv.fit(data, df['label'],validation_split=0.4, epochs = 3)

# %%
model_conv.predict(
    data, 
    batch_size=32, 
    verbose=1)

# %%
model_conv.predict_classes(data,batch_size=32,verbose=1)

# %%
from keras.layers import Input, Dense, LSTM, MaxPooling1D, Conv1D
from keras.models import Model

input_layer = Input(shape=(400, 16))
conv1 = Conv1D(filters=32,
               kernel_size=8,
               strides=1,
               activation='relu',
               padding='same')(input_layer)
lstm1 = LSTM(32, return_sequences=True)(conv1)
output_layer = Dense(1, activation='sigmoid')(lstm1)
model = Model(inputs=input_layer, outputs=output_layer)

model.summary()

# %%
# with pooling and merging
from keras.layers import Input, Dense, LSTM, MaxPooling1D, Conv1D
from keras.models import Model

input_layer = Input(shape=(400, 16))
conv1 = Conv1D(filters=32,
               kernel_size=8,
               strides=1,
               activation='relu')(input_layer)
pool1 = MaxPooling1D(pool_size=4)(conv1)
lstm1 = LSTM(32)(pool1)
output_layer = Dense(400, activation='sigmoid')(lstm1)
model_merging= Model(inputs=input_layer, outputs=output_layer)
model_merging.fit(data, df['label'],validation_split=0.4, epochs = 3)

model_merging.summary()

# %%
from keras.layers import merge
from keras.layers.core import *
from keras.layers.recurrent import LSTM
from keras.layers import Convolution2D
from keras.models import *
from keras.layers.normalization import BatchNormalization
from keras_attention_block import *

INPUT_DIM = 32
TIME_STEPS = 20
SINGLE_ATTENTION_VECTOR = False
APPLY_ATTENTION_BEFORE_LSTM = False

inputs = Input(shape=(TIME_STEPS, INPUT_DIM))
attention_mul =  SelfAttention1DLayer(similarity="linear",dropout_rate=0.2)(inputs)#MyLayer((20,32))(inputs)#
lstm_units = 32
#attention_mul = LSTM(lstm_units, return_sequences=False)(attention_mul)
attention_mul = Flatten()(attention_mul)
output = Dense(1, activation='sigmoid')(attention_mul)
m = Model(inputs=[inputs], outputs=output)

m.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
print(m.summary())


m.fit(data, df['label'],validation_split=0.4, epochs = 3)

# %%
from keras.models import Model, Sequential
from keras.layers import Input, Dense, LSTM, MaxPooling1D, Conv1D

from keras.layers import Input, Dense, Embedding, SpatialDropout1D, concatenate, Dropout,LSTM, Bidirectional
# modelBi = Sequential()
# modelBi.add(Bidirectional(LSTM(9, return_sequences=True),
#                         input_shape=(10, 9)))
# modelBi.add(Bidirectional(LSTM(9)))
# modelBi.add(Dense(10))
# modelBi.add(Activation('softmax'))
# modelBi.compile(loss='categorical_crossentropy', optimizer='rmsprop')
# modelBi.fit(data,df['label'] , epochs=1, batch_size=100 )
max_features=10
maxlen=9
modelB = Sequential()

modelB.add(Embedding(max_features, 128, input_length=maxlen))
modelB.add(Conv1D(64, 3, activation='relu', input_shape=(10, 9)))
modelB.add(Conv1D(64, 3, activation='relu'))
modelB.add(MaxPooling1D(3))
modelB.add(Bidirectional(LSTM(64)))
# modelB.add(Conv1D(32, 3, activation='relu'))
# modelB.add(Conv1D(32, 3, activation='relu'))
# modelB.add(Conv1D(64, 2, activation='relu', input_shape=(10, 9)))
modelB.add(Dropout(0.5))
modelB.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
modelB.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
# modelB.fit(data,df['label'] , epochs=3, batch_size=100 )
modelB.summary()

# %%
from sklearn.metrics import classification_report
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

y_pred_vonv = model_conv.predict(data)
y_predlstm = model_lstm.predict(data)
y_predmerg=  model_merging.predict(data)
y_predatten=m..predict(data)

# %%
from sklearn.metrics import classification_report
y_true =label

target_names = ['class 0', 'class 1']

print(classification_report(df['label'], y_pred_vonv))

# %%
from sklearn.metrics import classification_report
y_true =label
# >>> y_pred = [0, 0, 2, 2, 1]
target_names = ['class 0', 'class 1']

print(classification_report(df['label'], y_predlstm))

# %%
from sklearn.metrics import classification_report
y_true =label

target_names = ['class 0', 'class 1']

print(classification_report(df['label'], y_pred_vonv))

# %%
from sklearn.metrics import classification_report
y_true =label

target_names = ['class 0', 'class 1']

print(classification_report(df['label'], y_predmerg))

# %%
from sklearn.metrics import classification_report
y_true =label

target_names = ['class 0', 'class 1']

print(classification_report(df['label'], y_predatten))
